# %% [markdown]
# Se agrega la raiz del proyecto para importar las funciones

# %%
import sys
from pathlib import Path


base_path = Path.cwd().parent
sys.path.append(str(base_path))

# %% [markdown]
# Cargamos los datos y los almacenamos en un dataframe

# %%
from src.dengue import loader

data_folder = base_path / 'data' / 'raw'
pd = loader.cargar_sivigila(data_folder)
pd
# Out:
#        CONSECUTIVE COD_EVE     FEC_NOT SEMANA   ANO     COD_PRE COD_SUB EDAD  \
# 0          6481307     210  2019-11-09     45  2019  4746000051      02    7
# 1          6481308     210  2019-05-08     18  2019  4755500106      01    7
# 2          6481309     210  2019-01-22     03  2019  4755500106      01    6
# 3          6481310     210  2019-02-15     07  2019  4746000051      01    6
# 4          6481311     210  2019-06-25     25  2019  4755500106      01   25
# ...            ...     ...         ...    ...   ...         ...     ...  ...
# 761089    11653976     580  2024-05-12     20  2024  7652012492      01   46
# 761090    11653924     580  2024-08-15     33  2024  0500104648      02   87
# 761091    11653947     580  2024-06-05     23  2024  4100100572      01   88
# 761092    11653965     580  2024-04-30     18  2024  7300100944      01   38
# 761093    11653938     580  2024-04-13     15  2024  7600101125      01   57
#
# ...
