# %% [markdown]
# # 1. Introducción
#
# ## 1.1 Contexto del Dataset
#
# Este dataset proviene del Sistema de Vigilancia de Salud Publica (SIVIGILA), que recopila y analiza datos sobre eventos que afectan la salud de la poblacion colombiana: enfermedades infecciosas, cronicas, factores de riesgo y otros sucesos de importancia en salud publica.
#
# El dengue es un evento de notificacion obligatoria en Colombia desde la reemergencia de los años setenta. La notificacion se realiza de forma individual por las Unidades Primarias Generadoras de Datos (UPGD) al sistema SIVIGILA. Se manejan 3 eventos de notificacion relacionados al dengue: dengue (210), dengue grave (220) y mortalidad por dengue (580).
#
# El período de análisis comprende los cinco años más recientes disponibles en fuentes abiertas del INS (2019-2024). Este rango responde al requerimiento metodológico del canal endémico, componente solicitado dentro del alcance del proyecto, que demanda como mínimo cinco años de historia epidemiológica para construir una línea de base estable sobre el año de análisis. Como consecuencia de este criterio, el período incluye el ciclo epidémico de 2019, uno de los más relevantes registrados en Colombia y la Región de las Américas.
#
# [1.1.2. Situación epidemiológica en América](https://www.ins.gov.co/buscador-eventos/Lineamientos/Pro_Dengue.pdf)
#
# ## 1.2 Descripción del Conjunto de Datos
#
# Los datos se obtienen del portal oficial del INS - SIVIGILA:
# https://portalsivigila.ins.gov.co/Paginas/Buscador.aspx
#
# Cada fila representa un caso individual notificado con informacion demografica, geografica, clinica y administrativa.
#
# > Diccionario oficial: https://www.ins.gov.co/BibliotecaDigital/diccionario-xls-.pdf

# %% [markdown]
# ## 1.3 Diccionario de Datos
#
# | Variable | Tipo | Descripción |
# |---|---|---|
# | CONSECUTIVE | Numérico | Identificador único del registro de notificación |
# | COD_EVE | Numérico | Código del evento según el INS (210 = Dengue, 220 = Dengue grave, 580 = Mortalidad por dengue) |
# | FEC_NOT | Fecha | Fecha de notificación del caso al sistema SIVIGILA |
# | SEMANA | Numérico | Semana epidemiológica de notificación (rango: 1–53). Inicio de semana: domingo |
# | ANO | Numérico | Año epidemiológico correspondiente a la semana de notificación |
# | COD_PRE | Numérico | Código del prestador de servicios de salud (UPGD) que notifica |
# | COD_SUB | Numérico | Código de subsede del prestador notificador |
# | EDAD | Numérico | Edad del paciente al momento del evento |
# | UNI_MED | Numérico | Unidad de medida de la edad (1 = años, 2 = meses, 3 = días, 4 = horas, 5 = Minutos) |
# | nacionalidad | Numérico | Código de nacionalidad del paciente |
# | nombre_nacionalidad | Texto | Nombre de la nacionalidad del paciente |
# | SEXO | Texto | Sexo biológico del paciente (M = hombre, F = mujer, I = indeterminado) |
# | COD_PAIS_O | Numérico | Código internacional del país donde ocurrió el evento |
# | COD_DPTO_O | Numérico | Código DIVIPOLA del departamento de ocurrencia del evento |
# | COD_MUN_O | Numérico | Código DIVIPOLA del municipio de ocurrencia del evento |
# | AREA | Numérico | Área de residencia del paciente (1 = cabecera municipal, 2 = centro poblado, 3 = rural disperso) |
# | OCUPACION | Numérico | Código de ocupación del paciente según Decreto 654/2021 y Resolución 0771/2021 |
# | TIP_SS | Texto | Régimen de afiliación al SGSSS (C = contributivo, S = subsidiado, P = excepción, E = especial, N = no asegurado, I = indeterminado) |
# | COD_ASE | Numérico | Código de la EAPB/EPS a la que está afiliado el paciente |
# | PER_ETN | Numérico | Código de pertenencia étnica según clasificación DANE (1 = indígena, 2 = ROM/gitano, 3 = raizal, 4 = palenquero, 5 = Negro/Mulato/afrocolombiano, 6 = Otro) |
# | GRU_POB | Numérico | Código del grupo poblacional étnico específico |
# | nom_grupo | Texto | Nombre del grupo étnico o población especial (principalmente comunidades indígenas) |
# | estrato | Numérico | Estrato socioeconómico del paciente (1–6) |
# | GP_DISCAPA | Numérico | Persona con discapacidad (1 = sí, 2 = no) |
# | GP_DESPLAZ | Numérico | Víctima de desplazamiento forzado (1 = sí, 2 = no) |
# | GP_MIGRANT | Numérico | Migrante (1 = sí, 2 = no) |
# | GP_CARCELA | Numérico | Persona privada de la libertad (1 = sí, 2 = no) |
# | GP_GESTAN | Numérico | Paciente en estado de gestación (1 = sí, 2 = no) |
# | sem_ges | Numérico | Semana de gestación al momento de la notificación (>=1 AND <=45) |
# | GP_INDIGEN | Numérico | Habitante de calle (1 = sí, 2 = no) |
# | GP_POBICFB | Numérico | Población infantil bajo atención del ICBF (1 = sí, 2 = no) |
# | GP_MAD_COM | Numérico | Madre comunitaria (1 = sí, 2 = no) |
# | GP_DESMOVI | Numérico | Persona desmovilizada (1 = sí, 2 = no) |
# | GP_PSIQUIA | Numérico | Paciente institucionalizado en centro psiquiátrico (1 = sí, 2 = no) |
# | GP_VIC_VIO | Numérico | Víctima de violencia (1 = sí, 2 = no) |
# | GP_OTROS | Numérico | Pertenece a otro grupo poblacional no especificado (1 = sí, 2 = no) |
# | fuente | Numérico | Fuente de la notificación (1 = rutinaria, 2 = búsqueda activa institucional, 3 = Vigilancia intensificada, 4 = búsqueda activa comunitaria, 5 = investigaciones) |
# | COD_PAIS_R | Numérico | Código internacional del país de residencia del paciente |
# | COD_DPTO_R | Numérico | Código DIVIPOLA del departamento de residencia del paciente |
# | COD_MUN_R | Numérico | Código DIVIPOLA del municipio de residencia del paciente |
# | COD_DPTO_N | Numérico | Código DIVIPOLA del departamento donde se realizó la notificación |
# | COD_MUN_N | Numérico | Código DIVIPOLA del municipio donde se realizó la notificación |
# | FEC_CON | Fecha | Fecha de la primera consulta médica del paciente |
# | INI_SIN | Fecha | Fecha de inicio de síntomas referida por el paciente |
# | TIP_CAS | Numérico | Clasificación inicial del caso (1 = sospechoso, 2 = probable, 3 = confirmado por laboratorio, 4 = confirmado clínicamente, 5 = confirmado por nexo epidemiológico) |
# | PAC_HOS | Numérico | Indicador de hospitalización (1 = sí, 2 = no) |
# | FEC_HOS | Fecha | Fecha de hospitalización del paciente |
# | CON_FIN | Numérico | Condición final del paciente (0 = no sabe, 1 = vivo, 2 = muerto) |
# | FEC_DEF | Fecha | Fecha de defunción del paciente |
# | AJUSTE | Numérico | Clasificación final del caso tras ajuste (0 = no aplica, 3 = confirmado por laboratorio, 4 = confirmado clínicamente, 5 = confirmado por nexo epidemiológico, 6 = descartado, 7 = otro, D = Descarte por error de digitación) |
# | FECHA_NTO | Fecha | Fecha de nacimiento del paciente |
# | CER_DEF | Texto | Número del certificado de defunción |
# | CBMTE | Texto | Causa básica de muerte codificada en CIE X |
# | FEC_ARC_XL | Fecha | Fecha de creación de archivo plano |
# | FEC_AJU | Fecha | Fecha del último ajuste registrado para el caso |
# | FM_FUERZA | Texto | Fuerza militar a la que pertenece el paciente (cuando aplica) |
# | FM_UNIDAD | Texto | Unidad militar del paciente (cuando aplica) |
# | FM_GRADO | Texto | Grado militar del paciente (cuando aplica) |
# | confirmados | Numérico | Variable derivada que indica si el caso está confirmado, calculada a partir de AJUSTE |
# | consecutive_origen | Numérico | Consecutivo del registro original de referencia |
# | consecutive_12 | Numérico | Identificador alternativo del registro (99.8% nulos) |
# | va_sispro | Texto | Variable de validación cruzada con SISPRO |
# | Estado_final_de_caso | Numérico | Código numérico del estado final del caso tras proceso de ajuste |
# | nom_est_f_caso | Texto | Nombre descriptivo del estado final del caso |
# | Nom_upgd | Texto | Nombre de la Unidad Primaria Generadora de Datos (UPGD) que notificó el caso |
# | Particion | Texto | Variable administrativa generada al momento de exportar el archivo |
# | Pais_ocurrencia | Texto | Nombre del país de ocurrencia del evento |
# | Nombre_evento | Texto | Nombre del evento de interés en salud pública |
# | Departamento_ocurrencia | Texto | Nombre del departamento de ocurrencia del evento |
# | Municipio_ocurrencia | Texto | Nombre del municipio de ocurrencia del evento |
# | Pais_residencia | Texto | Nombre del país de residencia del paciente |
# | Departamento_residencia | Texto | Nombre del departamento de residencia del paciente |
# | Municipio_residencia | Texto | Nombre del municipio de residencia del paciente |
# | Departamento_Notificacion | Texto | Nombre del departamento donde se realizó la notificación |
# | Municipio_notificacion | Texto | Nombre del municipio donde se realizó la notificación |

# %% [markdown]
# # 2. Configuracion y Carga de Datos
#
# Se importan librerias y se usa la funcion cargar_sivigila definida en src/dengue/loader.py, que lee los archivos Excel anuales del portal SIVIGILA, los concatena y devuelve un unico DataFrame. Si existe el archivo Parquet, se carga directamente para mayor velocidad.

# %%
import sys
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import geopandas as gpd
import math

# %%
PROJECT_ROOT = Path("..").resolve()
sys.path.insert(0, str(PROJECT_ROOT / "src"))

DIR_RAW      = PROJECT_ROOT / "data/raw"
DIR_MAPPINGS = PROJECT_ROOT / "data/external/mappings"
DIR_LOOKUP   = PROJECT_ROOT / "data/external/lookup"
DIR_FIGURAS  = PROJECT_ROOT / "outputs/figures/eda"
PARQUET_CACHE = PROJECT_ROOT / "data/interim/sivigila_raw_2019_2024.parquet"
DIR_FIGURAS.mkdir(parents=True, exist_ok=True)

from dengue.loader import cargar_sivigila

if PARQUET_CACHE.exists():
    df_raw = pd.read_parquet(PARQUET_CACHE)
else:
    df_raw = cargar_sivigila(DIR_RAW)
    PARQUET_CACHE.parent.mkdir(parents=True, exist_ok=True)
    df_raw.to_parquet(PARQUET_CACHE, index=False)

# %%
print(f"Shape del dataset: {df_raw.shape[0]:,} filas x {df_raw.shape[1]} columnas")
print(f"Años disponibles: {sorted(df_raw['ANO'].dropna().unique())}")
print(f"Eventos (COD_EVE): {sorted(df_raw['COD_EVE'].dropna().unique())}")
# Out:
# Shape del dataset: 761,094 filas x 75 columnas
# Años disponibles: ['2019', '2020', '2021', '2022', '2023', '2024']
# Eventos (COD_EVE): ['210', '220', '580']

# %% [markdown]
# Se define la paleta de colores institucional para todas las visualizaciones del notebook.

# %%
INS_ROJO  = "#C8102E"
INS_AZUL  = "#003087"
INS_VERDE = "#00843D"
PALETA    = [INS_AZUL, INS_ROJO, INS_VERDE, "#F5A623", "#7B68EE", "#881DDA", "#FF6B6B", "#4ECDC4"]

# %% [markdown]
# # 3. Inspección y Calidad de los Datos
#
# Esta sección analiza la estructura, calidad y coherencia interna del dataset sin modificar ningún dato. Los hallazgos aqui fundamentan las decisiones de limpieza de la sección 4.
#
# | Sub-sección | Contenido |
# |---|---|
# | 3.1 | Perfil de variables |
# | 3.2 | Estadisticas descriptivas |
# | 3.3 | Distribución de COD_EVE |
# | 3.4 | Clasificación y Estado Final del Caso |
# | 3.5 | Valores fuera de rango esperado |
# | 3.6 | Cobertura de notificación por municipio |

# %% [markdown]
# ## 3.1 Perfil de Variables
#
# Para cada variable se reporta el tipo de dato, el numero y porcentaje de valores nulos, y el numero de valores unicos. Esta información, junto con el diccionario de datos, permite identificar variables con problemas de calidad y fundamentar las decisiones de limpieza de la sección 4.

# %%
nulos     = df_raw.isnull().sum()
pct_nulos = (df_raw.isnull().mean() * 100).round(1)
unicos    = df_raw.nunique()

inventario = pd.DataFrame({
    "tipo":      df_raw.dtypes,
    "nulos":     nulos,
    "pct_nulos": pct_nulos,
    "unicos":    unicos,
})

inventario = inventario.sort_values("pct_nulos", ascending=False)
display(inventario)
# Out:
#                              tipo   nulos  pct_nulos  unicos
# GRU_POB                    object  761094      100.0       0
# CBMTE                      object  760253       99.9      83
# CER_DEF                    object  760257       99.9     752
# FEC_DEF                    object  760269       99.9     615
# CONSECUTIVE_12             object  759255       99.8    1839
# ...                           ...     ...        ...     ...
# Municipio_ocurrencia       object       0        0.0    1030
# Municipio_residencia       object       6        0.0    1082
# Departamento_residencia    object       0        0.0      35
# Municipio_notificacion     object       0        0.0     899
# Departamento_Notificacion  object       0        0.0      33
#
# [75 rows x 4 columns]

# %% [markdown]
# El dataset crudo contiene 761.094 filas y 75 columnas, todas en formato texto. Ninguna tiene tipo numérico o fecha asignado por defecto, por lo que EDAD, SEMANA, ANO, estrato, todas las fechas y otras variables categóricas que se manejan con números requieren conversión explícita en la etapa de limpieza.
#
# Las variables núcleo FEC_NOT, ANO, SEMANA, EDAD, SEXO, AREA, COD_EVE, INI_SIN, FEC_CON y todos los códigos geográficos están completas o casi completas, lo que garantiza la viabilidad del análisis principal.
#
# Las variables CBMTE, CER_DEF y FEC_DEF presentan 99.9% de nulos, lo cual es esperado y correcto: solo los registros con COD_EVE=580 (mortalidad por dengue) tienen estos campos diligenciados. Su presencia habilita el análisis de mortalidad de la sección 5.10.
#
# Los valores faltantes en FEC_HOS (57.1%), sem_ges (40.6%) y nom_grupo (40.2%) son estructurales y justificados: cada variable aplica únicamente a una subpoblación específica.
#
# En la etapa de limpieza se realizarán las siguientes acciones. Primero, conversión de todas las variables a su tipo de dato correcto. Segundo, descarte de variables sin valor analítico, ya sea por estar fuera del foco de estudio o por calidad de dato deficiente: GRU_POB, CONSECUTIVE, consecutive_12, Particion, FM_FUERZA, FM_UNIDAD, FM_GRADO, consecutive_origen, COD_SUB, COD_PRE, FEC_AJU, FEC_ARC_XL, va_sispro y CER_DEF. Tercero, descarte de variables que violan la regla de no transitividad, es decir, columnas de texto que duplican información ya contenida en sus códigos correspondientes: Pais_ocurrencia, Pais_residencia, Nombre_evento, Departamento_ocurrencia, Municipio_ocurrencia, Departamento_residencia, Municipio_residencia, Departamento_Notificacion, Municipio_notificacion, nom_est_f_caso, nombre_nacionalidad y FECHA_NTO. Cuarto, creación de la variable derivada edad_anios a partir de EDAD y UNI_MED, tras lo cual ambas variables originales serán descartadas.

# %% [markdown]
# ## 3.2 Estadísticas Descriptivas
#
# Resumen estadístico de variables numéricas y frecuencias de variables categóricas clave. Para las numéricas se seleccionaron únicamente aquellas donde la media y el rango tienen interpretación directa; el resto son códigos de categorías o identificadores administrativos cuya estadística descriptiva no aporta.
#
# Variables numéricas incluidas: SEMANA, ANO, estrato, sem_ges y EDAD. SEMANA y ANO verifican la cobertura temporal del dataset. estrato refleja el perfil socioeconómico de los casos notificados. sem_ges aplica exclusivamente al subgrupo de gestantes con rango esperado de 1 a 45. EDAD se incluye con la salvedad de que su interpretación depende de UNI_MED, dado que la mayoría de registros están expresados en años, la media es aproximadamente válida para el conjunto, pero los percentiles bajos pueden estar distorsionados por registros en meses, días u horas. El análisis depurado de edad se realiza en la sección sociodemográfica tras convertir todos los registros a una unidad común.
#
# Variables categóricas incluidas: PAC_HOS y CON_FIN como indicadores clínicos del caso; SEXO, UNI_MED, AREA y PER_ETN como variables sociodemográficas; TIP_SS como indicador de afiliación al sistema; los campos GP_* analizados en bloque para cuantificar la representación de poblaciones vulnerables y evaluar su completitud como indicador de calidad; y fuente para identificar la proporción de notificación rutinaria frente a búsqueda activa.
#
# Excluidas de esta sección: COD_EVE se analiza en 3.3 y TIP_CAS, AJUSTE , Estado_final_de_caso y confirmados se tratan en detalle en 3.4. Las variables FM_* se excluyen porque OCUPACION ya captura la condición militar sin necesidad de subdesagregar por fuerza o grado. Nom_upgd y nom_grupo se omiten por su alta cardinalidad, y las variables de fecha se verifican en 3.5 junto con otros valores fuera de rango.

# %%
# varobles numericas claves
cols_num = ["SEMANA", "ANO", "EDAD", "sem_ges", "estrato"]
display(df_raw[cols_num].apply(pd.to_numeric, errors="coerce").describe().round(2))
# Out:
#           SEMANA        ANO       EDAD  sem_ges    estrato
# count  761094.00  761094.00  761094.00  3802.00  709292.00
# mean       26.19    2022.23      22.22    22.19       1.76
# std        14.80       1.93      18.52    10.09       0.87
# min         1.00    2019.00       1.00     1.00       1.00
# 25%        14.00    2020.00       9.00    13.00       1.00
# 50%        25.00    2023.00      16.00    23.00       2.00
# 75%        39.00    2024.00      31.00    31.00       2.00
# max        53.00    2024.00     124.00    41.00       6.00

# %%
cols_cat = [
    "PAC_HOS", "CON_FIN",
    "SEXO", "UNI_MED", "AREA", "PER_ETN",
    "TIP_SS",
    "GP_DISCAPA", "GP_DESPLAZ", "GP_MIGRANT", "GP_CARCELA", "GP_GESTAN", "GP_INDIGEN", "GP_POBICFB", 
    "GP_MAD_COM", "GP_DESMOVI", "GP_PSIQUIA", "GP_VIC_VIO", "GP_OTROS", 
    "fuente"
]

ncols = 3
nrows = math.ceil(len(cols_cat) / ncols)
fig, axes = plt.subplots(nrows, ncols, figsize=(18, nrows * 4))
axes = axes.flatten()

for i, col in enumerate(cols_cat):
    vc = df_raw[col].astype(str).str.strip().replace("nan", float("nan")).value_counts(dropna=True).sort_values(ascending=True)
    axes[i].barh(vc.index.astype(str), vc.values, color=INS_AZUL, edgecolor="white")
    axes[i].set_title(col, fontsize=10, fontweight="bold")
    axes[i].set_xlabel("Frecuencia", fontsize=8)
    axes[i].tick_params(axis="y", labelsize=8)

n_vars = len(cols_cat)
for j in range(n_vars, len(axes)):
    axes[j].set_visible(False)

plt.suptitle("Distribución de variables categóricas", fontsize=13, y=1.01)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "categoricas_grid.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Variables numéricas: el dataset cubre las semanas epidemiológicas 1 a 53 con una mediana en la semana 25, indicando distribución a lo largo de todo el año. Los años van de 2019 a 2024 con mediana en 2023, confirmando una mayor concentración de casos en el periodo 2023-2024 que 2019-2022. EDAD presenta una media de 22.22 y una mediana de 16, distribución asimétrica hacia edades jóvenes; sin embargo, dado que UNI_MED registra múltiples unidades, la media está potencialmente inflada por valores numéricos altos que corresponden a unidades menores, el máximo de 124 no puede clasificarse como error hasta construir edad_anios en la sección 3.5, pues un registro con EDAD=124 y UNI_MED=4 corresponde a un recién nacido de 124 horas, no un paciente de 124 años. sem_ges registra 3.802 valores, coherente con su aplicación exclusiva al subgrupo de gestantes, con rango 1 a 41 dentro de lo esperado. estrato presenta mediana de 2 indicando que el 50% de los casos se presentan en poblaciones vulnerables, sin valores fuera de rango.
#
# Variables categóricas: PAC_HOS muestra que la mayoría de casos no fueron hospitalizados, con una proporción menor hospitalizada. SEXO muestra distribución relativamente equilibrada con ligero predominio masculino. UNI_MED confirma que la gran mayoría de registros de edad están en años, con una fracción menor en meses y proporciones mínimas en días y horas. AREA está concentrada en cabecera municipal con presencia menor de rural disperso y centro poblado. PER_ETN está dominada por la categoría otro, con representación menor de afrocolombianos e indígenas. TIP_SS muestra predominio del régimen subsidiado seguido del contributivo, con proporciones pequeñas de excepción, no asegurado y especial. Todos los campos GP_* presentan el valor no como ampliamente dominante, lo que es esperable dado que son poblaciones específicas; no se observan valores fuera del rango permitido. fuente está dominada por notificación rutinaria con una fracción de búsqueda activa institucional y proporciones mínimas de otras fuentes.

# %% [markdown]
# ## 3.3 Distribucion de COD_EVE
#
# El campo COD_EVE define el tipo de evento notificado y determina que análisis aplica a cada registro: incidencia (210, 220) o mortalidad (580). Esta seccion examina la proporcion de cada evento.

# %%
conteo_cod_eve = (
    df_raw["COD_EVE"].astype(str).str.strip()
    .value_counts().reset_index()
)
conteo_cod_eve.columns = ["COD_EVE", "conteo"]
conteo_cod_eve["pct"] = (conteo_cod_eve["conteo"] / len(df_raw) * 100).round(2)

etiquetas = {"210": "Dengue (210)", "220": "Dengue grave (220)", "580": "Mortalidad (580)"}
conteo_cod_eve["label"] = conteo_cod_eve["COD_EVE"].map(etiquetas)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

wedges, _, autotexts = axes[0].pie(
    conteo_cod_eve["conteo"],
    labels=None,
    autopct="%1.1f%%",
    colors=[INS_AZUL, INS_VERDE, INS_ROJO],
    startangle=90,
    pctdistance=0.75,
    wedgeprops={"edgecolor": "white", "linewidth": 1.5}
)
for at in autotexts:
    at.set_color("white")
    at.set_fontsize(9)
axes[0].legend(
    wedges, conteo_cod_eve["label"],
    loc="lower center", bbox_to_anchor=(0.5, -0.12),
    fontsize=9, frameon=False
)
axes[0].set_title("Distribución por tipo de evento", fontsize=11)

detalle = conteo_cod_eve[conteo_cod_eve["COD_EVE"].isin(["220", "580"])]
axes[1].barh(detalle["label"], detalle["conteo"], color=[INS_VERDE, INS_ROJO], edgecolor="white")
for i, (val, pct) in enumerate(zip(detalle["conteo"], detalle["pct"])):
    axes[1].text(val + 200, i, f"{val:,} ({pct}%)", va="center", fontsize=9)
axes[1].set_xlabel("Registros")
axes[1].set_title("Detalle: dengue grave y mortalidad", fontsize=11)

plt.suptitle("Distibución de COD_EVE (210, 220, 580)", fontsize=12)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "distribucion_cod_eve.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# El dengue (210) concentra el 98.7% de los registros (751,114 casos), mientras que el dengue grave (220) representa el 1.21% (9,227 casos) y la mortalidad por dengue (580) el 0.1% (753 casos). Esta proporcion es coherente con la piramide de severidad esperada: la gran mayoria de infecciones cursan como dengue sin signos de alarma y con signos de alarma, una fraccion menor evoluciona a dengue grave y solo un porcentaje minimo resulta en muerte. Los 753 registros de mortalidad, aunque minoritarios, son suficientes para el analisis de la seccion 5.10.

# %% [markdown]
# ## 3.4 Clasificación y Estado Final del Caso
#
# Los campos TIP_CAS, AJUSTE, confirmados y Estado_final_de_caso determinan conjuntamente el ciclo de vida de un caso en SIVIGILA, desde su clasificación inicial hasta su estado definitivo tras el proceso de ajuste. El protocolo INS indica que deben excluirse los registros con AJUSTE = 6 (descartado) y AJUSTE = D (error de digitación) antes de cualquier análisis. Esta subsección documenta la distribución real de los tres campos y detecta valores inesperados o inconsistencias entre ellos.

# %%
fig, axes = plt.subplots(1, 4, figsize=(24, 5))

# TIP_CAS
vc_tip = df_raw["TIP_CAS"].astype(str).str.strip().value_counts(dropna=True).sort_values(ascending=True)
etiquetas_tip = {"1": "Sospechoso (1)", "2": "Probable (2)", "3": "Conf. lab (3)",
                 "4": "Conf. clinica (4)", "5": "Conf. nexo (5)"}
vc_tip.index = [etiquetas_tip.get(x, x) for x in vc_tip.index]
axes[0].barh(vc_tip.index, vc_tip.values, color=INS_AZUL, edgecolor="white")
axes[0].set_title("TIP_CAS - clasificacion inicial")
axes[0].set_xlabel("Frecuencia")

# AJUSTE
vc_aju = df_raw["AJUSTE"].astype(str).str.strip().value_counts(dropna=True).sort_values(ascending=True)
etiquetas_aju = {"0": "No aplica (0)", "3": "Conf. lab (3)", "4": "Conf. clinica (4)",
                 "5": "Conf. nexo (5)", "6": "Descartado (6)", "7": "Otro (7)", "D": "Error digitacion (D)"}
vc_aju.index = [etiquetas_aju.get(x, x) for x in vc_aju.index]
axes[1].barh(vc_aju.index, vc_aju.values, color=INS_AZUL, edgecolor="white")
axes[1].set_title("AJUSTE - clasificacion final")
axes[1].set_xlabel("Frecuencia")

# Estado_final_de_caso
vc_est = df_raw["Estado_final_de_caso"].astype(str).str.strip().value_counts(dropna=True).sort_values(ascending=True)
axes[2].barh(vc_est.index, vc_est.values, color=INS_AZUL, edgecolor="white")
axes[2].set_title("Estado_final_de_caso")
axes[2].set_xlabel("Frecuencia")

# confirmados
vc_conf = df_raw["confirmados"].astype(str).str.strip().value_counts(dropna=True).sort_values(ascending=True)
etiquetas_conf = {"0": "No confirmado (0)", "1": "Confirmado (1)"}
vc_conf.index = [etiquetas_conf.get(x, x) for x in vc_conf.index]
axes[3].barh(vc_conf.index, vc_conf.values, color=INS_AZUL, edgecolor="white")
axes[3].set_title("confirmados - variable derivada")
axes[3].set_xlabel("Frecuencia")

plt.suptitle("Clasificacion y estado final del caso", fontsize=13)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "clasificacion_casos.png", dpi=150, bbox_inches="tight")
plt.show()

# Cruce de las 4 variables
print("\nCruce TIP_CAS vs AJUSTE vs Estado_final_de_caso vs confirmados:")
display(
    df_raw.assign(
        TIP_CAS=df_raw["TIP_CAS"].astype(str).str.strip(),
        AJUSTE=df_raw["AJUSTE"].astype(str).str.strip(),
        Estado_final_de_caso=df_raw["Estado_final_de_caso"].astype(str).str.strip(),
        confirmados=df_raw["confirmados"].astype(str).str.strip()
    )
    .groupby(["TIP_CAS", "AJUSTE", "Estado_final_de_caso", "confirmados"])
    .size()
    .reset_index(name="conteo")
    .sort_values(['TIP_CAS', 'AJUSTE', 'Estado_final_de_caso', 'confirmados'], ascending=True)
    .reset_index(drop=True)
)

# Registros a excluir segun protocolo INS
n_descartados = df_raw["AJUSTE"].astype(str).str.strip().isin(["6", "D"]).sum()
pct_descartados = n_descartados / len(df_raw) * 100
print(f"\nRegistros con AJUSTE 6 o D (a excluir en seccion 4): {n_descartados:,} ({pct_descartados:.2f}%)")

# Inconsistencias
inconsistencias = df_raw[
    (df_raw["confirmados"].astype(str).str.strip() == "1") &
    (df_raw["AJUSTE"].astype(str).str.strip().isin(["6", "D"]))
].shape[0]
print(f"Inconsistencias confirmados=1 con AJUSTE descartado: {inconsistencias:,}")
# Out:
# Cruce TIP_CAS vs AJUSTE vs Estado_final_de_caso vs confirmados:
#    TIP_CAS AJUSTE Estado_final_de_caso confirmados  conteo
# 0        2      0                    2           0  183172
# 1        2      3                    3           1  241792
# 2        2      5                    5           1   37480
# 3        2      7                    2           0   30208
# 4        3      0                    3           1  201644
# 5        3      3                    3           1   32511
# 6        3      5                    5           1     231
# 7        3      7                    3           1   29481
# 8        5      0                    5           1    2968
# 9        5      3                    3           1     475
# 10       5      5                    5           1     547
# 11       5      7                    5           1     585
# Registros con AJUSTE 6 o D (a excluir en seccion 4): 0 (0.00%)
# Inconsistencias confirmados=1 con AJUSTE descartado: 0

# %% [markdown]
# TIP_CAS está dominado por casos probables (2), patrón esperado en SIVIGILA dado que la mayoría de notificaciones ocurren sin confirmación de laboratorio en el momento del reporte. En AJUSTE la categoría más frecuente es no aplica (0), seguida de confirmado por laboratorio (3). Las distribuciones de Estado_final_de_caso y confirmados son coherentes entre sí.
#
# La ausencia de confirmación clínica (AJUSTE=4) es coherente con la naturaleza del dengue: su presentación clínica se superpone con la de otras arbovirosis como el chikungunya y el zika, lo que dificulta la confirmación por criterio clínico exclusivo y lleva a que la mayoría de los casos queden como probables o sean confirmados por laboratorio.
#
# El cruce de las cuatro variables produjo 12 combinaciones únicas, todas internamente consistentes. Las tres más frecuentes concentran la mayoría de los registros: casos probables sin ajuste final que permanecen no confirmados (TIP_CAS=2, AJUSTE=0, confirmados=0) con 183.172 registros, casos probables confirmados por laboratorio tras el ajuste (TIP_CAS=2, AJUSTE=3, confirmados=1) con 241.792, y casos ya confirmados por laboratorio desde la clasificación inicial sin necesidad de ajuste (TIP_CAS=3, AJUSTE=0, confirmados=1) con 201.644. No se detectaron inconsistencias entre confirmados y AJUSTE en ninguna de las 12 combinaciones.
#
# El campo AJUSTE no presenta registros con valor 6 (descartado) ni D (error de digitación), por lo que el universo analítico conserva los 761.094 registros originales. Los valores presentes son 0, 3, 5 y 7, todos correspondientes a estados válidos según el protocolo INS. No se requiere filtrado por registros descartados; el filtro por confirmados=1 se aplicará en el módulo de predicción, donde el modelo trabaja exclusivamente sobre casos confirmados de dengue. En el componente analítico el universo de trabajo se define indicador por indicador según lo establece el protocolo INS.

# %% [markdown]
# ## 3.5 Valores Fuera de Rango Esperado
#
# Revisión de variables con rangos definidos por el protocolo INS o la lógica del dominio. Para las variables numéricas y categóricas se verifican límites esperados según el diccionario de datos; para las variables de fecha se revisan nulos, registros fuera del período de estudio y consistencia entre fechas relacionadas.

# %%
# construccion de edad_anios para validacion
divisores = {"1": 1, "2": 12, "3": 365, "4": 8760, "5": 525600}
edad_num = pd.to_numeric(df_raw["EDAD"], errors="coerce")
uni_med = df_raw["UNI_MED"].astype(str).str.strip()
edad_anios = edad_num / uni_med.map(divisores).astype(float)

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

# edad_anios
axes[0].boxplot(edad_anios.dropna(), vert=False, patch_artist=True,
                boxprops=dict(facecolor=INS_AZUL, color=INS_AZUL),
                medianprops=dict(color="white", linewidth=2),
                whiskerprops=dict(color=INS_AZUL), capprops=dict(color=INS_AZUL),
                flierprops=dict(marker="o", color=INS_AZUL, alpha=0.3, markersize=3))
axes[0].set_title("edad_anios - edad convertida a años")
axes[0].set_xlabel("Edad en años")
axes[0].set_yticks([])
n_edad_invalida = ((edad_anios > 120) | (edad_anios < 0)).sum()
axes[0].text(0.98, 0.95, f"Valores > 120 o negativos: {n_edad_invalida:,}",
             transform=axes[0].transAxes, ha="right", va="top", fontsize=8,
             color="red" if n_edad_invalida > 0 else "green")

# UNI_MED
vc_uni = df_raw["UNI_MED"].astype(str).str.strip().value_counts().sort_index()
etiquetas_uni = {"1": "Años (1)", "2": "Meses (2)", "3": "Días (3)", "4": "Horas (4)", "5": "Minutos (5)"}
vc_uni.index = [etiquetas_uni.get(x, x) for x in vc_uni.index]
axes[1].barh(vc_uni.index, vc_uni.values, color=INS_AZUL, edgecolor="white")
axes[1].set_title("UNI_MED - unidad de medida de edad")
axes[1].set_xlabel("Frecuencia")
n_uni_inv = (~df_raw["UNI_MED"].astype(str).str.strip().isin(["1","2","3","4","5"])).sum()
axes[1].text(0.98, 0.95, f"Valores fuera de rango: {n_uni_inv:,}",
             transform=axes[1].transAxes, ha="right", va="top", fontsize=8,
             color="red" if n_uni_inv > 0 else "green")

# SEMANA
semana_num = pd.to_numeric(df_raw["SEMANA"], errors="coerce")
axes[2].hist(semana_num.dropna(), bins=53, color=INS_AZUL, edgecolor="white")
axes[2].set_title("SEMANA - distribución epidemiológica")
axes[2].set_xlabel("Semana")
axes[2].set_ylabel("Frecuencia")
n_semana_inv = ((semana_num < 1) | (semana_num > 53)).sum()
axes[2].text(0.98, 0.95, f"Fuera de 1-53: {n_semana_inv:,}",
             transform=axes[2].transAxes, ha="right", va="top", fontsize=8,
             color="red" if n_semana_inv > 0 else "green")

# ESTRATO
estrato_num = pd.to_numeric(df_raw["estrato"], errors="coerce")
vc_estrato = estrato_num.dropna().astype(int).value_counts().sort_index()
axes[3].bar(vc_estrato.index.astype(str), vc_estrato.values, color=INS_AZUL, edgecolor="white")
axes[3].set_title("estrato - distribución socioeconómica")
axes[3].set_xlabel("Estrato")
axes[3].set_ylabel("Frecuencia")
n_estrato_inv = (~estrato_num.dropna().astype(int).isin([1,2,3,4,5,6])).sum()
axes[3].text(0.98, 0.95, f"Fuera de 1-6: {n_estrato_inv:,}",
             transform=axes[3].transAxes, ha="right", va="top", fontsize=8,
             color="red" if n_estrato_inv > 0 else "green")

# sem_ges
sem_ges_num = pd.to_numeric(df_raw["sem_ges"], errors="coerce")
axes[4].boxplot(sem_ges_num.dropna(), vert=False, patch_artist=True,
                boxprops=dict(facecolor=INS_AZUL, color=INS_AZUL),
                medianprops=dict(color="white", linewidth=2),
                whiskerprops=dict(color=INS_AZUL), capprops=dict(color=INS_AZUL),
                flierprops=dict(marker="o", color=INS_AZUL, alpha=0.3, markersize=3))
axes[4].set_title("sem_ges - semana de gestación")
axes[4].set_xlabel("Semana gestacional")
axes[4].set_yticks([])
n_semges_inv = ((sem_ges_num < 1) | (sem_ges_num > 42)).sum()
axes[4].text(0.98, 0.95, f"Fuera de 1-42: {n_semges_inv:,}",
             transform=axes[4].transAxes, ha="right", va="top", fontsize=8,
             color="red" if n_semges_inv > 0 else "green")

axes[5].set_visible(False)

plt.suptitle("Valores fuera de rango esperado - variables numéricas y categóricas", fontsize=13)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "valores_fuera_rango_vars.png", dpi=150, bbox_inches="tight")
plt.show()

# resumen numerico
print("Resumen edad_anios:")
display(edad_anios.describe().round(5))
print(f"\nRegistros con edad_anios > 120 o negativos: {n_edad_invalida:,}")
# Out:
# Resumen edad_anios:
# count    761094.00000
# mean         22.08779
# std          18.64250
# min           0.00002
# 25%           9.00000
# 50%          16.00000
# 75%          31.00000
# max         124.00000
# dtype: float64
# Registros con edad_anios > 120 o negativos: 3

# %%
fecha_cols = ["FEC_NOT", "INI_SIN", "FEC_CON", "FEC_HOS", "FEC_DEF", "FECHA_NTO"]
fecha_labels = ["Notificación", "Inicio síntomas", "Primera consulta",
                "Hospitalización", "Defunción", "Nacimiento"]

resumen_fechas = []
for col, label in zip(fecha_cols, fecha_labels):
    serie = pd.to_datetime(df_raw[col], errors="coerce")
    n_nulos = serie.isna().sum()
    resumen_fechas.append({
        "Variable": col,
        "Descripción": label,
        "Nulos": n_nulos,
        "% Nulos": round(n_nulos / len(df_raw) * 100, 2),
        "Min observado": serie.min().date() if pd.notna(serie.min()) else None,
        "Max observado": serie.max().date() if pd.notna(serie.max()) else None
    })

df_fechas = pd.DataFrame(resumen_fechas)
display(df_fechas)

# histogramas - excluye FECHA_NTO por escala
fecha_cols_hist = ["FEC_NOT", "INI_SIN", "FEC_CON", "FEC_HOS", "FEC_DEF"]
fecha_labels_hist = ["Notificación", "Inicio síntomas", "Primera consulta",
                     "Hospitalización", "Defunción"]

fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

for i, (col, label) in enumerate(zip(fecha_cols_hist, fecha_labels_hist)):
    serie = pd.to_datetime(df_raw[col], errors="coerce").dropna()
    axes[i].hist(serie, bins=50, color=INS_AZUL, edgecolor="white")
    axes[i].set_title(f"{col} - {label}")
    axes[i].set_xlabel("Fecha")
    axes[i].set_ylabel("Frecuencia")
    axes[i].tick_params(axis="x", rotation=45)

axes[5].set_visible(False)

plt.suptitle("Distribución de variables de fecha - dataset crudo", fontsize=13)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "distribucion_fechas.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
#     Variable       Descripción   Nulos  % Nulos Min observado Max observado
# 0    FEC_NOT      Notificación       0     0.00    2018-12-30    2025-03-29
# 1    INI_SIN   Inicio síntomas       0     0.00    2018-12-21    2024-12-28
# 2    FEC_CON  Primera consulta       1     0.00    2018-12-23    2025-02-03
# 3    FEC_HOS   Hospitalización  434557    57.10    2018-12-23    2025-03-18
# 4    FEC_DEF         Defunción  760269    99.89    2018-12-30    2024-12-18
# 5  FECHA_NTO        Nacimiento    2269     0.30    1900-01-01    2024-12-18

# %% [markdown]
# La edad presenta una mediana aproximada de 16 anos con el 50% de los casos concentrado entre los 9 y 31 años, lo que indica una afectación predominante en población joven. Se identificaron 3 registros con edad superior a 120 años que seran corregidos en la etapa de limpieza. La unidad de medida confirma que practicamente la totalidad de los registros expresan la edad en años (UNI_MED = 1), con una fracción minima en meses y dias que requerira normalización.
#
# El estrato socioeconomico se concentra fuertemente en los niveles 1 y 2, lo cual es coherente con el perfil poblacional del Magdalena y con la mayor exposición al vector en zonas de menor infraestructura sanitaria.
#
# En cuanto a rangos, FEC_NOT, INI_SIN y FEC_CON presentan mínimos en diciembre
# de 2018, ligeramente fuera del período de estudio 2019–2024. Esto es consistente
# con el flujo normal de notificación de SIVIGILA: casos con inicio de síntomas en
# las últimas semanas de 2018 pueden haber sido notificados formalmente en la primera
# semana epidemiológica de 2019, quedando registrados en el archivo correspondiente
# a ese año. Dado que la unidad de análisis del presente estudio es la semana
# epidemiológica de notificación, estos registros son válidos y se conservan sin
# modificación. FEC_NOT tiene un máximo de 2025-03-29 y FEC_CON de 2025-02-03, lo cual es coherente con el rezago natural del sistema de notificación: casos ocurridos a finales de 2024 pueden ser notificados o consultados en los primeros meses de 2025. FECHA_NTO muestra un mínimo de 1900-01-01, valor claramente inválido que indica un error de digitación en al menos un registro.
#
# Las gráficas de distribución anual confirman el comportamiento epidémico esperado: pico marcado en 2024 en todas las variables clínicas, coherente con el ciclo epidémico 2023-2024 documentado por el INS. FEC_DEF sigue el mismo patrón pero en escala mucho menor dado el bajo volumen de fallecidos.

# %% [markdown]
# ## 3.6 Cobertura de Notificación por Municipio
#
# Numero de semanas epidemiologicas con al menos un caso notificado por municipio y año. Un valor de 0 indica que el municipio no reporto ningun caso durante ese ano completo.

# %%
_df = df_raw.copy()
_df["ANO"] = pd.to_numeric(_df["ANO"], errors="coerce")
_df["SEMANA"] = pd.to_numeric(_df["SEMANA"], errors="coerce")
_df = (
    _df[_df["COD_DPTO_O"].astype(str).str.lstrip("0") == "47"]
    .dropna(subset=["COD_MUN_O", "ANO", "SEMANA"])
)

anos_disponibles = sorted(_df["ANO"].unique().astype(int))

semanas_con_casos = (
    _df.groupby(["COD_MUN_O", "ANO", "SEMANA"])
    .size()
    .reset_index(name="casos")
    .groupby(["COD_MUN_O", "ANO"])
    .size()
    .reset_index(name="sem_con_casos")
)

pivot_cobertura = semanas_con_casos.pivot(
    index="COD_MUN_O", columns="ANO", values="sem_con_casos"
).fillna(0)

_muns = (
    pd.read_excel(DIR_MAPPINGS / "Davipola.xlsx", dtype=str)
    .assign(cod_municipio=lambda d: "47" + d["cod_municipio"].astype(str).str.strip().str[-3:])
    .query("cod_departamento.str.strip().str.lstrip('0') == '47'", engine="python")
    [["cod_municipio", "municipio"]]
    .drop_duplicates()
)

pivot_cobertura = pivot_cobertura.reset_index()
pivot_cobertura["COD_MUN_O"] = "47" + pivot_cobertura["COD_MUN_O"].astype(str).str.strip().str.zfill(3)
pivot_cobertura = pivot_cobertura.merge(_muns, left_on="COD_MUN_O", right_on="cod_municipio", how="left")
pivot_cobertura["municipio"] = pivot_cobertura["municipio"].fillna(pivot_cobertura["COD_MUN_O"])
pivot_cobertura = (
    pivot_cobertura
    .set_index("municipio")
    .drop(columns=["COD_MUN_O", "cod_municipio"], errors="ignore")
    .sort_values(anos_disponibles[-1], ascending=False)
)

fig, ax = plt.subplots(figsize=(len(anos_disponibles) + 3, len(pivot_cobertura) * 0.38 + 2))
sns.heatmap(pivot_cobertura, ax=ax, cmap="Blues", vmin=0, vmax=53,
            linewidths=0.3, linecolor="white", annot=True, fmt=".0f")
ax.set_title("Semanas con al menos un caso notificado por municipio y año - Magdalena")
ax.set_xlabel("Año")
ax.set_ylabel("")
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "cobertura_notificacion.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Santa Marta mantiene la cobertura más alta y consistente del departamento con más de 49 semanas notificadas por año, seguida de Cienaga y Zona Bananera. Los municipios con cobertura más baja como Pedraza, Zapayan, Cerro de San Antonio y Remolino presentan periodos prolongados sin notificación que podrian reflejar problemas de acceso a la red de vigilancia más que ausencia real de casos.
#
# El año 2020 muestra una caida generalizada en la cobertura de notificación en casi todos los municipios, consistente con la interrupcion de los servicios de salud durante la pandemia de COVID-19.
#
# Se identificaron 7 registros con código de municipio 000, que no corresponde a ningún municipio valido del Magdalena. Estos registros se conservan en el dataset crudo y su origen se analiza a continuación.

# %% [markdown]
# Dado que en la sección 3.6 se identificaron registros con COD_MUN_O = 000, se analiza su origen cruzando con Pais_ocurrencia y Municipio_ocurrencia.

# %%
display(
    df_raw[df_raw["COD_MUN_O"].astype(str).str.strip() == "000"]
    [["COD_MUN_O", "Pais_ocurrencia", "Municipio_ocurrencia"]]
    .value_counts()
    .reset_index()
    .rename(columns={0: "conteo"})
)
# Out:
#    COD_MUN_O Pais_ocurrencia                         Municipio_ocurrencia  \
# 0        000        COLOMBIA              * TOLIMA. MUNICIPIO DESCONOCIDO
# 1        000        COLOMBIA           * MAGDALENA. MUNICIPIO DESCONOCIDO
# 2        000        COLOMBIA                * META. MUNICIPIO DESCONOCIDO
# 3        000        COLOMBIA                   * LA GUAJIRA SIN MUNICIPIO
# 4        000        COLOMBIA        * CUNDINAMARCA. MUNICIPIO DESCONOCIDO
# 5        000        COLOMBIA                    * PROCEDENCIA DESCONOCIDA
# 6        000        COLOMBIA             * BOLIVAR. MUNICIPIO DESCONOCIDO
# 7        000        COLOMBIA             * CORDOBA. MUNICIPIO DESCONOCIDO
# 8        000        COLOMBIA             * VICHADA. MUNICIPIO DESCONOCIDO
# 9        000        COLOMBIA           * SANTANDER. MUNICIPIO DESCONOCIDO
# 10       000        COLOMBIA            * PUTUMAYO. MUNICIPIO DESCONOCIDO
# 11       000        COLOMBIA            * AMAZONAS. MUNICIPIO DESCONOCIDO
# 12       000        COLOMBIA           * ANTIOQUIA. MUNICIPIO DESCONOCIDO
# 13       000        COLOMBIA  * NORTE DE SANTANDER. MUNICIPIO DESCONOCIDO
# 14       000        COLOMBIA           * ATLANTICO. MUNICIPIO DESCONOCIDO
# 15       000        COLOMBIA               * CESAR. MUNICIPIO DESCONOCIDO
# 16       000        COLOMBIA               * CAUCA. MUNICIPIO DESCONOCIDO
# 17       000        COLOMBIA            * CASANARE. MUNICIPIO DESCONOCIDO
# 18       000        COLOMBIA               * CHOCO. MUNICIPIO DESCONOCIDO
# 19       000        COLOMBIA               * HUILA. MUNICIPIO DESCONOCIDO
# 20       000        COLOMBIA             * GUAINIA. MUNICIPIO DESCONOCIDO
# 21       000        COLOMBIA   * SAN ANDRES Y PROV. MUNICIPIO DESCONOCIDO
# 22       000        COLOMBIA              * VAUPES. MUNICIPIO DESCONOCIDO
#
#     count
# 0      23
# 1      14
# 2       9
# 3       8
# 4       7
# 5       6
# 6       5
# 7       5
# 8       4
# 9       3
# 10      3
# 11      3
# 12      3
# 13      3
# 14      3
# 15      2
# 16      2
# 17      2
# 18      2
# 19      1
# 20      1
# 21      1
# 22      1

# %%
display(
    df_raw[df_raw["Pais_ocurrencia"].astype(str).str.strip() != "COLOMBIA"]
    [["COD_MUN_O", "Pais_ocurrencia", "Municipio_ocurrencia"]]
    .value_counts()
    .reset_index()
    .rename(columns={0: "conteo"})
)
# Out:
#    COD_MUN_O                            Pais_ocurrencia  \
# 0        862                                  VENEZUELA
# 1        076                                     BRASIL
# 2        604                                       PERÚ
# 3        484                                     MÉXICO
# 4        214                       REPÚBLICA DOMINICANA
# 5        218                                    ECUADOR
# 6        192                                       CUBA
# 7        591                                     PANAMÁ
# 8        032                                  ARGENTINA
# 9        320                                  GUATEMALA
# 10       840                  ESTADOS UNIDOS DE AMÉRICA
# 11       531                                    CURACAO
# 12       356                                      INDIA
# 13       188                                 COSTA RICA
# 14       068                                    BOLIVIA
# 15       140                   REPÚBLICA CENTROAFRICANA
# 16       276                                   ALEMANIA
# 17       826  REINO UNIDO DE GRAN BRETAÑA E IRLANDA DEL
# 18       630                                PUERTO RICO
# 19       152                                      CHILE
# 20       528                               PAÍSES BAJOS
# 21       724                                     ESPAÑA
# 22       533                                      ARUBA
# 23       056                                    BÉLGICA
# 24       446                                      MACAO
# 25       124                                     CANADÁ
# 26       178                REPUBLICA POPULAR DEL CONGO
# 27       600                                   PARAGUAY
# 28       340                                   HONDURAS
# 29       474                                  MARTINICA
# 30       222                                EL SALVADOR
# 31       191                                    CROACIA
# 32       156                                      CHINA
# 33       175                                    MAYOTTE
# 34       188                                 COSTA RICA
# 35       052                                   BARBADOS
# 36       004                                 AFGANISTÁN
# 37       008                                    ALBANIA
# 38       036                                  AUSTRALIA
# 39       044                                    BAHAMAS
# 40       050                                 BANGLADESH
# 41       090                              ISLAS SALOMÓN
# 42       174                                    COMORAS
# 43       246                                  FINLANDIA
# 44       226                          GUINEA ECUATORIAL
# 45       434                     JAMAHIRIYA ÁRABE LIBIA
# 46       404                                      KENYA
# 47       372                                    IRLANDA
# 48       270                                     GAMBIA
# 49       340                                   HONDURAS
# 50       332                                      HAITÍ
# 51       250                                    FRANCIA
# 52       380                                     ITALIA
# 53       398                                 KAZAJSTÁN
# 54       531                                    CURACAO
# 55       516                                    NAMIBIA
# 56       666                       SAN PEDRO Y MIGUELON
# 57       818                                     EGIPTO
# 58       858                                    URUGUAY
#
#                                  Municipio_ocurrencia  count
# 0                                  EXTERIOR_VENEZUELA   1436
# 1                                     EXTERIOR_BRASIL    233
# 2                                       EXTERIOR_PERU     71
# 3                                     EXTERIOR_MÉXICO     52
# 4                       EXTERIOR_REPÚBLICA DOMINICANA     33
# 5                                    EXTERIOR_ECUADOR     31
# 6                                       EXTERIOR_CUBA     29
# 7                                     EXTERIOR_PANAMA     19
# 8                                  EXTERIOR_ARGENTINA     15
# 9                                  EXTERIOR_GUATEMALA     15
# 10                            EXTERIOR_ESTADOS UNIDOS      9
# 11                                   EXTERIOR_CURACAO      5
# 12                                     EXTERIOR_INDIA      5
# 13                                         COSTA RICA      5
# 14                                   EXTERIOR_BOLIVIA      5
# 15                  EXTERIOR_REPÚBLICA CENTROAFRICANA      4
# 16                                  EXTERIOR_ALEMANIA      4
# 17  EXTERIOR_REINO UNIDO DE GRAN BRETAÑA E IRLANDA...      4
# 18                               EXTERIOR_PUERTO RICO      4
# 19                                     EXTERIOR_CHILE      4
# 20                              EXTERIOR_PAÍSES BAJOS      3
# 21                                    EXTERIOR_ESPAÑA      3
# 22                                     EXTERIOR_ARUBA      3
# 23                                   EXTERIOR_BÉLGICA      3
# 24                                     EXTERIOR_MACAO      2
# 25                                    EXTERIOR_CANADÁ      2
# 26              EXTERIOR_REPUBLICA POPULAR DEL CONGO       2
# 27                                  EXTERIOR_PARAGUAY      2
# 28                                           HONDURAS      2
# 29                                 EXTERIOR_MARTINICA      2
# 30                               EXTERIOR_EL SALVADOR      1
# 31                                   EXTERIOR_CROACIA      1
# 32                                     EXTERIOR_CHINA      1
# 33                                            MAYOTTE      1
# 34                                EXTERIOR_COSTA RICA      1
# 35                                  EXTERIOR_BARBADOS      1
# 36                                EXTERIOR_AFGANISTÁN      1
# 37                                   EXTERIOR_ALBANIA      1
# 38                                 EXTERIOR_AUSTRALIA      1
# 39                                   EXTERIOR_BAHAMAS      1
# 40                                EXTERIOR_BANGLADESH      1
# 41                             EXTERIOR_ISLAS SALOMÓN      1
# 42                                  EXTERIOR_COMORAS       1
# 43                                          FINLANDIA      1
# 44                         EXTERIOR_GUINEA ECUATORIAL      1
# 45                             JAMAHIRIYA ARABE LIBIA      1
# 46                                     EXTERIOR_KENYA      1
# 47                                   EXTERIOR_IRLANDA      1
# 48                                    EXTERIOR_GAMBIA      1
# 49                                  EXTERIOR_HONDURAS      1
# 50                                     EXTERIOR_HAITÍ      1
# 51                                   EXTERIOR_FRANCIA      1
# 52                                    EXTERIOR_ITALIA      1
# 53                                          KAZAJSTAN      1
# 54                                            CURACAO      1
# 55                                   EXTERIOR_NAMIBIA      1
# 56                      EXTERIOR_SAN PEDRO Y MIGUELON      1
# 57                                    EXTERIOR_EGIPTO      1
# 58                                   EXTERIOR_URUGUAY      1

# %% [markdown]
# Los registros con COD_MUN_O = 000 corresponden exclusivamente a casos ocurridos en Colombia donde el municipio de ocurrencia no pudo ser identificado al momento de la notificación. El sistema registra etiquetas como municipio desconocido o procedencia desconocida. No estan relacionados con casos extranjeros y se trata de un error de registro.
#
# Los casos con pais de ocurrencia distinto a Colombia (59 combinaciones, encabezadas por Venezuela con 1,436 registros) tienen codigos de municipio propios de cada pais y no corresponden a ningún municipio colombiano. Ambos grupos se conservan en df_raw. En la sección 4.1 se validaran todos los codigos de municipio de registros colombianos contra el catalogo DIVIPOLA para identificar posibles casos adicionales con codigos invalidos.

# %% [markdown]
# # 4. Preparación del Dataset Analítico
#
# Esta sección construye df_clean a partir de df_raw aplicando únicamente las transformaciones que la sección 3 demostró ser necesarias. df_raw se conserva intacto en todo momento; df_clean es una copia transformada.
#
# | Sub-sección | Contenido |
# |---|---|
# | 4.1 | Descarte de variables |
# | 4.2 | Conversión de tipos, estandarización de columnas y texto |
# | 4.3 | Normalización y validación de edad|
# | 4.4 | Marcado de municipios válidos |
# | 4.5 | Carga de tablas de referencia |
# | 4.6 | Incorporación de nombres de referencia |
# | 4.7 | Guardar dataset consolidado |

# %% [markdown]
# ## 4.1 Descarte de Variables
#
# Se eliminan variables en dos bloques. El primero agrupa variables sin valor analítico por estar fuera del foco de estudio o por calidad de dato deficiente. El segundo agrupa variables que violan la regla de no transitividad, es decir, columnas de texto que duplican información ya contenida en sus códigos correspondientes.
#
# **Bloque 1 - Sin valor analítico**
#
# | Variable | Justificación |
# |---|---|
# | CONSECUTIVE, consecutive_origen, CONSECUTIVE_12 | Identificadores de registro sin valor analítico |
# | Partición | Variable administrativa generada al momento de exportar el archivo |
# | COD_SUB | Código de subsede sin uso en el análisis |
# | COD_PRE | Código de prestador sin uso en el análisis |
# | GRU_POB | 100% nulos en todos los años |
# | FEC_ARC_XL, FEC_AJU | Fechas administrativas sin valor epidemiológico |
# | FM_FUERZA, FM_UNIDAD, FM_GRADO | El análisis sociolaboral se realiza con OCUPACION; no se subdesagrega por fuerza o grado |
# | va_sispro | Variable de validación interna SISPRO sin uso analítico |
# | CER_DEF | Número de certificado de defunción sin valor analítico para este estudio |
#
# **Bloque 2 - No transitividad**
#
# | Variable | Justificación |
# |---|---|
# | nombre_nacionalidad | Redundante con el código nacionalidad |
# | nom_est_f_caso | Redundante con Estado_final_de_caso |
# | Nombre_evento | Redundante con COD_EVE |
# | Pais_ocurrencia, Departamento_ocurrencia, Municipio_ocurrencia | Redundantes con códigos DIVIPOLA; los nombres se incorporan vía merge en 4.6 |
# | Pais_residencia, Departamento_residencia, Municipio_residencia | Mismo caso |
# | Departamento_Notificacion, Municipio_notificacion | Mismo caso |
# | FECHA_NTO | Fecha de nacimiento se descarta; la edad del paciente al momento del evento se captura a través de edad y uni_med |
# | EDAD, UNI_MED | Reemplazadas por edad_anios normalizada; se descartan después del paso 4.3 |

# %%
cols_descartar = [
    "CONSECUTIVE", "consecutive_origen", "CONSECUTIVE_12", "Partición" ,"COD_SUB", "COD_PRE",
    "GRU_POB", "FEC_ARC_XL", "FEC_AJU",
    "FM_FUERZA", "FM_UNIDAD", "FM_GRADO",
    "va_sispro", "CER_DEF",
    "nombre_nacionalidad", 
    "nom_est_f_caso", "Nombre_evento",
    "Pais_ocurrencia", "Departamento_ocurrencia", "Municipio_ocurrencia",
    "Pais_residencia", "Departamento_residencia", "Municipio_residencia",
    "Departamento_Notificacion", "Municipio_notificacion",
    "FECHA_NTO"
]

df_clean = df_raw.copy()

cols_descartar = [c for c in cols_descartar if c in df_clean.columns]
df_clean = df_clean.drop(columns=cols_descartar)
print(f"Variables descartadas: {len(cols_descartar)}")
print(f"Columnas restantes: {df_clean.shape[1]}")

df_clean.info()
# Out:
# Variables descartadas: 26
# Columnas restantes: 49
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 761094 entries, 0 to 761093
# Data columns (total 49 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   COD_EVE               761094 non-null  object
#  1   FEC_NOT               761094 non-null  object
#  2   SEMANA                761094 non-null  object
#  3   ANO                   761094 non-null  object
#  4   EDAD                  761094 non-null  object
#  5   UNI_MED               761094 non-null  object
#  6   nacionalidad          761094 non-null  object
#  7   SEXO                  761094 non-null  object
#  8   COD_PAIS_O            761094 non-null  object
#  9   COD_DPTO_O            761094 non-null  object
#  10  COD_MUN_O             761094 non-null  object
#  11  AREA                  761094 non-null  object
#  12  OCUPACION             761094 non-null  object
#  13  TIP_SS                761094 non-null  object
#  14  COD_ASE               741255 non-null  object
#  15  PER_ETN               761094 non-null  object
#  16  nom_grupo             454802 non-null  object
#  17  estrato               747950 non-null  object
#  18  GP_DISCAPA            761094 non-null  object
#  19  GP_DESPLAZ            761094 non-null  object
#  20  GP_MIGRANT            761094 non-null  object
#  21  GP_CARCELA            761094 non-null  object
#  22  GP_GESTAN             761094 non-null  object
#  23  sem_ges               451743 non-null  object
#  24  GP_INDIGEN            761094 non-null  object
#  25  GP_POBICFB            761094 non-null  object
#  26  GP_MAD_COM            761094 non-null  object
#  27  GP_DESMOVI            761094 non-null  object
#  28  GP_PSIQUIA            761094 non-null  object
#  29  GP_VIC_VIO            761094 non-null  object
#  30  GP_OTROS              761094 non-null  object
#  31  fuente                760202 non-null  object
#  32  COD_PAIS_R            635983 non-null  object
#  33  COD_DPTO_R            761094 non-null  object
#  34  COD_MUN_R             761094 non-null  object
#  35  COD_DPTO_N            761094 non-null  object
#  36  COD_MUN_N             761094 non-null  object
#  37  FEC_CON               761093 non-null  object
#  38  INI_SIN               761094 non-null  object
#  39  TIP_CAS               761094 non-null  object
#  40  PAC_HOS               761094 non-null  object
#  41  FEC_HOS               326537 non-null  object
#  42  CON_FIN               761094 non-null  object
#  43  FEC_DEF               825 non-null     object
#  44  AJUSTE                761094 non-null  object
#  45  CBMTE                 841 non-null     object
#  46  confirmados           761094 non-null  object
#  47  Estado_final_de_caso  761094 non-null  object
#  48  Nom_upgd              758023 non-null  object
# dtypes: object(49)
# memory usage: 284.5+ MB

# %% [markdown]
# ## 4.2 Conversión de Tipos y Estandarización de Texto
#
# Se realizan dos acciones en este orden. Primero, estandarización a minúsculas de nombres de columnas y contenido de variables de texto (SEXO, TIP_SS, Nom_upgd, CBMTE, nom_grupo, COD_ASE) para garantizar consistencia en el código a lo largo del notebook. Segundo, conversión explícita de variables numéricas y de fecha a su tipo de dato correcto, dado que la sección 3.1 confirmó que todas las columnas llegan como object. OCUPACION se trata por separado al convertirse a Float64 por contener códigos con decimales significativos.
#
# **Variables de fecha**
#
# | Variable |
# |---|
# | FEC_NOT, FEC_CON, INI_SIN, FEC_HOS, FEC_DEF |
#
# **Variables numéricas enteras**
#
# | Grupo | Variables |
# |---|---|
# | Evento y tiempo | COD_EVE, SEMANA, ANO, EDAD, UNI_MED |
# | Identificación | nacionalidad |
# | Geografía ocurrencia | COD_PAIS_O, COD_DPTO_O, COD_MUN_O |
# | Sociodemográficas | AREA, OCUPACION, PER_ETN, estrato, sem_ges |
# | Grupos poblacionales | GP_DISCAPA, GP_DESPLAZ, GP_MIGRANT, GP_CARCELA, GP_GESTAN, GP_INDIGEN, GP_POBICFB, GP_MAD_COM, GP_DESMOVI, GP_PSIQUIA, GP_VIC_VIO, GP_OTROS |
# | Notificación | fuente |
# | Geografía residencia | COD_PAIS_R, COD_DPTO_R, COD_MUN_R |
# | Geografía notificación | COD_DPTO_N, COD_MUN_N |
# | Clasificación clínica | TIP_CAS, PAC_HOS, CON_FIN, AJUSTE, confirmados, Estado_final_de_caso |

# %%
# estandarizar nombres de columnas a minusculas
df_clean.columns = df_clean.columns.str.lower()

# estandarizacion de contenido de texto a minusculas
cols_texto = ["sexo", "tip_ss", "nom_upgd", "cbmte", "nom_grupo", "cod_ase"]
for col in cols_texto:
    if col in df_clean.columns:
        df_clean[col] = df_clean[col].astype(str).str.strip().str.lower().replace({"nan": pd.NA, "none": pd.NA}) #type: ignore

# fechas
cols_fecha = ["fec_not", "fec_con", "ini_sin", "fec_hos", "fec_def"]
for col in cols_fecha:
    df_clean[col] = pd.to_datetime(df_clean[col], errors="coerce")

# ocupacion
df_clean["ocupacion"] = pd.to_numeric(df_clean["ocupacion"], errors="coerce").astype("Float64")

# numericas enteras
cols_int = [
    "cod_eve", "semana", "ano", "edad", "uni_med",
    "nacionalidad",
    "cod_pais_o", "cod_dpto_o", "cod_mun_o",
    "area", "per_etn", "estrato", "sem_ges",
    "gp_discapa", "gp_desplaz", "gp_migrant", "gp_carcela", "gp_gestan",
    "gp_indigen", "gp_pobicfb", "gp_mad_com", "gp_desmovi", "gp_psiquia",
    "gp_vic_vio", "gp_otros",
    "fuente",
    "cod_pais_r", "cod_dpto_r", "cod_mun_r",
    "cod_dpto_n", "cod_mun_n",
    "tip_cas", "pac_hos", "con_fin", "ajuste", "confirmados", "estado_final_de_caso"
]
for col in cols_int:
    if col in df_clean.columns:
        df_clean[col] = pd.to_numeric(df_clean[col], errors="coerce").astype("Int64")


print(f"Filas: {df_clean.shape[0]:,} | Columnas: {df_clean.shape[1]}")
print("\nTipos de dato:")
display(df_clean.dtypes.astype(str).value_counts().reset_index().rename(columns={"index": "dtype", "count": "columnas"}))
# Out:
# Filas: 761,094 | Columnas: 49
#
# Tipos de dato:
#             dtype  columnas
# 0           Int64        37
# 1          object         6
# 2  datetime64[ns]         5
# 3         Float64         1

# %% [markdown]
# ## 4.3 Normalización y Validación de Edad
#
# Se construye la variable derivada edad_anios convirtiendo edad a años según la unidad de medida registrada en uni_med. La sección 3.5 confirmó que existen registros en meses, días, horas y minutos que inflarían la distribución si se usara edad directamente.
#
# **Tabla de conversión**
#
# | uni_med | Unidad | Divisor |
# |---|---|---|
# | 1 | Años | 1 |
# | 2 | Meses | 12 |
# | 3 | Días | 365 |
# | 4 | Horas | 8760 |
# | 5 | Minutos | 525600 |
#
# Una vez calculada edad_anios se aplica la siguiente validación: valores superiores a 120 años se imputan como nulo por corresponder a errores de digitación confirmados en la sección 3.5, pero si tras la conversión el resultado sigue siendo mayor a 120 sí es un error real. Finalmente se descartan edad y uni_med

# %%
# conversion de edad a anos
divisores = {1: 1, 2: 12, 3: 365, 4: 8760, 5: 525600}
df_clean["edad_anios"] = (
    df_clean["edad"] / df_clean["uni_med"].map(divisores)
).round(2)

# validacion — valores mayores a 120 se imputan como nulo
n_invalidos = (df_clean["edad_anios"] > 120).sum()
df_clean.loc[df_clean["edad_anios"] > 120, "edad_anios"] = pd.NA
print(f"Registros con edad_anios > 120 imputados como nulo: {n_invalidos:,}")

# validacion — valores negativos
n_negativos = (df_clean["edad_anios"] < 0).sum()
df_clean.loc[df_clean["edad_anios"] < 0, "edad_anios"] = pd.NA
print(f"Registros con edad_anios negativa imputados como nulo: {n_negativos:,}")

# descarte de eda Y uni_med
df_clean = df_clean.drop(columns=["edad", "uni_med"], errors="ignore")

# verificacion
print(f"\nDistribución edad_anios:")
print(df_clean["edad_anios"].describe().round(2))
print(f"Nulos en edad_anios: {df_clean['edad_anios'].isna().sum():,}")
# Out:
# Registros con edad_anios > 120 imputados como nulo: 3
# Registros con edad_anios negativa imputados como nulo: 0
#
# Distribución edad_anios:
# count    761091.0
# mean        22.09
# std         18.64
# min           0.0
# 25%           9.0
# 50%          16.0
# 75%          31.0
# max         120.0
# Name: edad_anios, dtype: Float64
# Nulos en edad_anios: 3

# %% [markdown]
# Se encontraron 3 registros en esta condición, imputados como nulo. No se encontraron valores negativos. La distribución resultante muestra una mediana de 16 años y un máximo de 120, coherente con el perfil epidemiológico del dengue. Finalmente se descartan edad y uni_med.

# %% [markdown]
# ## 4.4 Marcado de Municipios Válidos
#
# Se crea la columna auxiliar mun_valido mediante validación de cod_mun_o contra el catálogo DIVIPOLA. Los registros con código inválido se conservan en df_clean y quedan excluidos automáticamente en los análisis que requieran municipio válido, sin necesidad de intervención manual adicional.

# %%
# carga del catalogo DIVIPOLA
divipola = (
    pd.read_excel(DIR_MAPPINGS / "Davipola.xlsx", dtype=str)
    .assign(cod_municipio=lambda d: d["cod_municipio"].astype(str).str.strip())
)
codigos_validos = set(pd.to_numeric(divipola["cod_municipio"], errors="coerce").dropna().astype("Int64").unique())

# construir codigo completo en df_clean
df_clean["cod_mun_completo"] = pd.to_numeric(
    df_clean["cod_dpto_o"].astype(str).str.strip() +
    df_clean["cod_mun_o"].astype(str).str.strip().str.zfill(3),
    errors="coerce"
).astype("Int64")

# marcado
df_clean["mun_valido"] = df_clean["cod_mun_completo"].isin(codigos_validos)

# verificacion
n_validos = df_clean["mun_valido"].sum()
n_invalidos = (~df_clean["mun_valido"]).sum()
print(f"Municipios válidos:   {n_validos:,} ({n_validos/len(df_clean)*100:.2f}%)")
print(f"Municipios inválidos: {n_invalidos:,} ({n_invalidos/len(df_clean)*100:.2f}%)")

df_clean
# Out:
# Municipios válidos:   758,911 (99.71%)
# Municipios inválidos: 2,183 (0.29%)
#         cod_eve    fec_not  semana   ano  nacionalidad sexo  cod_pais_o  \
# 0           210 2019-11-09      45  2019           170    m         170
# 1           210 2019-05-08      18  2019           170    m         170
# 2           210 2019-01-22       3  2019          <NA>    f         170
# 3           210 2019-02-15       7  2019          <NA>    f         170
# 4           210 2019-06-25      25  2019           170    m         170
# ...         ...        ...     ...   ...           ...  ...         ...
# 761089      580 2024-05-12      20  2024           170    f         170
# 761090      580 2024-08-15      33  2024           170    f         170
# 761091      580 2024-06-05      23  2024           170    f         170
# 761092      580 2024-04-30      18  2024           170    f         170
# 761093      580 2024-04-13      15  2024           170    f         170
#
#         cod_dpto_o  cod_mun_o  area  ...  con_fin    fec_def ajuste  cbmte  \
# 0               47        460     2  ...        1        NaT      7   <NA>
# 1               47        460     1  ...        1        NaT      0   <NA>
# 2               47        460     1  ...        1        NaT      0   <NA>
# 3               47        460     1  ...        1        NaT      0   <NA>
# 4               47        460     3  ...        1        NaT      0   <NA>
# ...            ...        ...   ...  ...      ...        ...    ...    ...
# 761089          76        520     1  ...        2 2024-05-12      3   r578
# 761090           5        579     2  ...        2 2024-08-15      3   a90x
# 761091          41         26     3  ...        2 2024-06-04      3   r571
# 761092          73        226     3  ...        2 2024-04-30      3   a91x
# 761093          19        212     3  ...        2 2024-04-12      3   r578
#
#        confirmados  estado_final_de_caso  \
# 0                1                     3
# 1                1                     3
# 2                1                     3
# 3                1                     3
# 4                1                     3
# ...            ...                   ...
# 761089           1                     3
# 761090           1                     3
# 761091           1                     3
# 761092           1                     3
# 761093           1                     3
#
#                                       nom_upgd  edad_anios  cod_mun_completo  \
# 0                    centro de salud los andes         7.0             47460
# 1                        ese fray luis de leon         7.0             47460
# 2                        ese fray luis de leon         6.0             47460
# 3          ese hospital local de nueva granada         6.0             47460
# 4                        ese fray luis de leon        25.0             47460
# ...                                        ...         ...               ...
# 761089               gyo medical ips - palmira        46.0             76520
# 761090                    clinica del prado sa        87.0              5579
# 761091                         clinica uros sa        88.0             41026
# 761092                       clinica ibague sa        38.0             73226
# 761093  clinica nuestra señora de los remedios        57.0             19212
#
#         mun_valido
# 0             True
# 1             True
# 2             True
# 3             True
# 4             True
# ...            ...
# 761089        True
# 761090        True
# 761091        True
# 761092        True
# 761093        True
#
# [761094 rows x 50 columns]

# %% [markdown]
# El 99.71% de los registros (758.911) tienen municipio válido. Los 2.183 registros restantes (0.29%) corresponden a casos donde el municipio de ocurrencia no pudo ser identificado al momento de la notificación o el pais de ocurrencia no era Colombia, situación documentada en la sección 3.6.

# %% [markdown]
# ## 4.5 Carga de Tablas de Referencia
#
# | Archivo | Columnas clave | Uso |
# |---|---|---|
# | Davipola.xlsx | cod_departamento, cod_municipio, municipio, departamento | Nombres de municipios y departamentos; subconjunto de 30 municipios de Magdalena para análisis departamental |
# | ocupaciones.xlsx | cod_ocu, cod_antiguo, nom_ocu | Nombre de ocupación del paciente; cod_antiguo se usa como clave secundaria para registros con códigos históricos |
# | aseguradoras.xls | cod_ase, nom_ase | Nombre de la EAPB/EPS |
# | TablaReferencia_CIE10__1.xlsx | Codigo, Nombre | Causa básica de muerte (solo cod_eve=580) |
# | paises.xlsx | codnumpais, pais | Nombre del país de ocurrencia y residencia |

# %%
# Cargar todas las tablas de referencia 

# DIVIPOLA: departamentos y municipios
davipola  = pd.read_excel(DIR_MAPPINGS / "Davipola.xlsx", dtype=str)
dptos_dv  = davipola[["cod_departamento", "departamento"]].drop_duplicates()
muns_dv   = davipola[["cod_municipio", "municipio"]].drop_duplicates()
muns_dv_mag = (
    davipola[davipola["cod_departamento"] == "47"][["cod_municipio", "municipio"]]
    .drop_duplicates()
)

# Ocupaciones
ocupaciones = (
    pd.read_excel(DIR_MAPPINGS / "ocupaciones.xlsx", dtype=str)
    [["cod_ocu", "cod_antiguo", "nombre_vigente_ocupacion"]]
    .rename(columns={"nombre_vigente_ocupacion": "nom_ocu"})
    .drop_duplicates(subset="cod_ocu", keep="first")
)

# Aseguradoras (EAPB)
aseguradoras = (
    pd.read_excel(DIR_MAPPINGS / "aseguradoras.xls", dtype=str, engine="xlrd")
    [["cod_ase", "nom_ase"]]
    .assign(cod_ase=lambda d: d["cod_ase"].astype(str).str.strip().str.lower())
    .drop_duplicates(subset="cod_ase", keep="first")
)

# Tabla CIE-10
cie10 = (
    pd.read_excel(DIR_MAPPINGS / "TablaReferencia_CIE10__1.xlsx", dtype=str)
    [["Codigo", "Nombre"]]
    .assign(Codigo=lambda d: d["Codigo"].astype(str).str.strip().str.lower())
    .drop_duplicates(subset="Codigo", keep="first")
)

# Paises
paises = pd.read_excel(DIR_MAPPINGS / "paises.xlsx", dtype=str)
paises = paises[["codnumpais", "pais"]].drop_duplicates()

print("Tablas de referencia cargadas:")
print(f"  DIVIPOLA departamentos: {len(dptos_dv)} filas")
print(f"  DIVIPOLA municipios:    {len(muns_dv)} filas")
print(f"  Municipios Magdalena:   {len(muns_dv_mag)} municipios")
print(f"  Ocupaciones:            {len(ocupaciones)} filas")
print(f"  Aseguradoras:           {len(aseguradoras)} filas")
print(f"  CIE-10:                 {len(cie10)} filas")
print(f"  Paises:                 {len(paises)} filas")
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
# Tablas de referencia cargadas:
#   DIVIPOLA departamentos: 33 filas
#   DIVIPOLA municipios:    1124 filas
#   Municipios Magdalena:   30 municipios
#   Ocupaciones:            1031 filas
#   Aseguradoras:           517 filas
#   CIE-10:                 12634 filas
#   Paises:                 253 filas

# %% [markdown]
# ## 4.6 Incorporación de Nombres de Referencia
#
# Se agregan columnas de nombre legible a df_clean mediante left joins con las tablas de referencia cargadas en 4.5. El tipo left garantiza que no se pierda ningún registro del dataset principal. Se valida después de cada join que el número de filas no cambie y que los nulos generados sean esperados. El join de CIE-10 se realiza exclusivamente sobre los registros con COD_EVE=580 y el resultado se incorpora al dataset completo.

# %%
n_antes = len(df_clean)

# departamento de ocurrencia
df_clean = df_clean.merge(
    dptos_dv.rename(columns={"cod_departamento": "cod_dpto_o", "departamento": "nom_dpto_o"})
    .assign(cod_dpto_o=lambda d: pd.to_numeric(d["cod_dpto_o"], errors="coerce").astype("Int64")),
    on="cod_dpto_o", how="left"
)

# municipio de ocurrencia
df_clean = df_clean.merge(
    muns_dv.rename(columns={"cod_municipio": "cod_mun_completo", "municipio": "nom_mun_o"})
    .assign(cod_mun_completo=lambda d: pd.to_numeric(d["cod_mun_completo"], errors="coerce").astype("Int64")),
    on="cod_mun_completo", how="left"
)

# pais de ocurrencia
df_clean = df_clean.merge(
    paises.rename(columns={"codnumpais": "cod_pais_o", "pais": "nom_pais_o"})
    .assign(cod_pais_o=lambda d: pd.to_numeric(d["cod_pais_o"], errors="coerce").astype("Int64")),
    on="cod_pais_o", how="left"
)

# ocupacion
# merge por codigo nuevo
df_clean = df_clean.merge(
    ocupaciones[["cod_ocu", "nom_ocu"]]
    .assign(cod_ocu=lambda d: pd.to_numeric(d["cod_ocu"], errors="coerce").astype("Float64"))
    .drop_duplicates(subset="cod_ocu", keep="first")
    .rename(columns={"cod_ocu": "ocupacion", "nom_ocu": "nom_ocupacion"}),
    on="ocupacion", how="left"
)
# para los que no encontraron nombre, buscar por codigo antiguo
sin_nombre = df_clean["nom_ocupacion"].isna()
df_clean.loc[sin_nombre, "nom_ocupacion"] = df_clean.loc[sin_nombre, "ocupacion"].map(
    ocupaciones
    .assign(cod_antiguo=lambda d: pd.to_numeric(d["cod_antiguo"], errors="coerce").astype("Float64"))
    .dropna(subset=["cod_antiguo"])
    .drop_duplicates(subset="cod_antiguo", keep="first")
    .set_index("cod_antiguo")["nom_ocu"]
)

# aseguradora
df_clean = df_clean.merge(
    aseguradoras.assign(cod_ase=lambda d: d["cod_ase"].astype(str).str.strip()),
    on="cod_ase", how="left"
)

# CIE-10 solo sobre cod_eve=580
reemplazos_cbmte = {
    "j15x": "j159",
    "i49x": "i499",
    "d65": "d65x",
    "8888": pd.NA,
    "9999": pd.NA,
    "none": pd.NA
}
df_clean["cbmte"] = df_clean["cbmte"].replace(reemplazos_cbmte)
df_clean = df_clean.merge(
    cie10.rename(columns={"Codigo": "cbmte", "Nombre": "nom_cbmte"}),
    on="cbmte", how="left"
)

assert len(df_clean) == n_antes, f"El merge modificó el número de filas: {len(df_clean):,} vs {n_antes:,}"
print(f"Filas conservadas: {len(df_clean):,}")
print(f"Columnas finales:  {df_clean.shape[1]}")

# nulos esperados por join
for col in ["nom_dpto_o", "nom_mun_o", "nom_pais_o", "nom_ocupacion", "nom_ase", "nom_cbmte"]:
    n = df_clean[col].isna().sum()
    print(f"  {col}: {n:,} nulos ({n/len(df_clean)*100:.2f}%)")
# Out:
# Filas conservadas: 761,094
# Columnas finales:  56
#   nom_dpto_o: 2,042 nulos (0.27%)
#   nom_mun_o: 2,183 nulos (0.29%)
#   nom_pais_o: 0 nulos (0.00%)
#   nom_ocupacion: 293 nulos (0.04%)
#   nom_ase: 19,856 nulos (2.61%)
#   nom_cbmte: 760,266 nulos (99.89%)

# %% [markdown]
# nom_cbmte presenta 99.89% de nulos (760.268 registros), lo cual es estructuralmente esperado dado que solo aplica a los 753 registros con cod_eve=580. Previo al merge se corrigieron tres códigos con formato incompleto: j15x e i49x tenían la subcategoría representada con x en lugar del dígito 9 que corresponde a la subdivisión no especificada en CIE-10, quedando como j159 e i499 respectivamente; d65 fue completado a d65x siguiendo el mismo criterio, ya que el código válido en la tabla CIE-10 incluye el sufijo x. Los valores 8888, 9999 y none fueron imputados como nulo por ser indicadores de ausencia de información y no códigos reales. Con estas correcciones, los 15 registros restantes de cbmte que no encontraron coincidencia en la tabla CIE-10 quedaron con nom_cbmte nulo, y se documentan como limitación de calidad en la fuente.
#
# nom_ase presenta 2.61% de nulos (19.856 registros). De estos, 19.839 corresponden a registros donde cod_ase es nulo en origen. Los 17 restantes corresponden a tres códigos presentes en el dataset pero ausentes en la tabla de referencia: [epss14](https://docs.supersalud.gov.co/PortalWeb/Juridica/Resoluciones/R_2013_Norma_000806.pdf) (Humana Vivir S.A., liquidada por la Superintendencia Nacional de Salud mediante Resolución 806 de 2013), [epss09](https://docs.supersalud.gov.co/PortalWeb/Juridica/Resoluciones/R_2014_Norma_000361.pdf) (EPS Comfenalco Antioquia, cerrada definitivamente en 2014) y 999999 (código estándar SIVIGILA para población pobre no asegurada y casos sin información de aseguramiento).
#
# nom_ocupacion presenta 0.04% de nulos (293 registros) por códigos de ocupación registrados con formato incompleto en SIVIGILA, dígitos faltantes o truncados que impiden el cruce con la tabla de referencia. El volumen es despreciable para el análisis.
#
# nom_mun_o presenta 0.29% de nulos (2.183 registros) y nom_dpto_o 0.27% (2.042 registros) por dos razones documentadas en la sección 3.6: casos ocurridos fuera de Colombia cuyos códigos de municipio y departamento no existen en el catálogo DIVIPOLA, y casos con código 000 que indica municipio no identificado al momento de la notificación. Ambos grupos están correctamente marcados como mun_valido=False.

# %% [markdown]
# ## 4.7 Guardado de df_clean
#
# Se guarda el DataFrame consolidado para reutilizarlo en el notebook de fuentes climaticas (02) sin tener que repetir todo el procesamiento de carga, limpieza y enriquecimiento.

# %%
ruta_processed = PROJECT_ROOT / Path("data/processed")
ruta_processed.mkdir(parents=True, exist_ok=True)

df_clean.to_parquet(ruta_processed / "df_clean.parquet", index=False)
print(f"df_clean guardado: {ruta_processed / 'df_clean.parquet'}")
print(f"Shape: {df_clean.shape}")
print(f"Columnas: {len(df_clean.columns)}")
# Out:
# df_clean guardado: C:\Users\edavi\PROYECTOS\dengue-surveillance-magdalena\data\processed\df_clean.parquet
#   Shape: (761094, 56)
#   Columnas: 56

# %%
df_clean
# Out:
#         cod_eve    fec_not  semana   ano  nacionalidad sexo  cod_pais_o  \
# 0           210 2019-11-09      45  2019           170    m         170
# 1           210 2019-05-08      18  2019           170    m         170
# 2           210 2019-01-22       3  2019          <NA>    f         170
# 3           210 2019-02-15       7  2019          <NA>    f         170
# 4           210 2019-06-25      25  2019           170    m         170
# ...         ...        ...     ...   ...           ...  ...         ...
# 761089      580 2024-05-12      20  2024           170    f         170
# 761090      580 2024-08-15      33  2024           170    f         170
# 761091      580 2024-06-05      23  2024           170    f         170
# 761092      580 2024-04-30      18  2024           170    f         170
# 761093      580 2024-04-13      15  2024           170    f         170
#
#         cod_dpto_o  cod_mun_o  area  ...  \
# 0               47        460     2  ...
# 1               47        460     1  ...
# 2               47        460     1  ...
# 3               47        460     1  ...
# 4               47        460     3  ...
# ...            ...        ...   ...  ...
# 761089          76        520     1  ...
# 761090           5        579     2  ...
# 761091          41         26     3  ...
# 761092          73        226     3  ...
# 761093          19        212     3  ...
#
#                                       nom_upgd edad_anios cod_mun_completo  \
# 0                    centro de salud los andes        7.0            47460
# 1                        ese fray luis de leon        7.0            47460
# 2                        ese fray luis de leon        6.0            47460
# 3          ese hospital local de nueva granada        6.0            47460
# 4                        ese fray luis de leon       25.0            47460
# ...                                        ...        ...              ...
# 761089               gyo medical ips - palmira       46.0            76520
# 761090                    clinica del prado sa       87.0             5579
# 761091                         clinica uros sa       88.0            41026
# 761092                       clinica ibague sa       38.0            73226
# 761093  clinica nuestra señora de los remedios       57.0            19212
#
#         mun_valido       nom_dpto_o      nom_mun_o  nom_pais_o  \
# 0             True        Magdalena  Nueva Granada    COLOMBIA
# 1             True        Magdalena  Nueva Granada    COLOMBIA
# 2             True        Magdalena  Nueva Granada    COLOMBIA
# 3             True        Magdalena  Nueva Granada    COLOMBIA
# 4             True        Magdalena  Nueva Granada    COLOMBIA
# ...            ...              ...            ...         ...
# 761089        True  Valle del Cauca        Palmira    COLOMBIA
# 761090        True        Antioquia  Puerto Berrío    COLOMBIA
# 761091        True            Huila       Altamira    COLOMBIA
# 761092        True           Tolima         Cunday    COLOMBIA
# 761093        True            Cauca        Corinto    COLOMBIA
#
#                                 nom_ocupacion                   nom_ase  \
# 0                                  Estudiante            MUTUAL SER ESS
# 1                                  Estudiante            MUTUAL SER ESS
# 2                         Hogar (ama de casa)            MUTUAL SER ESS
# 3                                   No aplica        COOSALUD ESS EPS-S
# 4       Personas que realizan trabajos varios        COOSALUD ESS EPS-S
# ...                                       ...                       ...
# 761089  Personas que realizan trabajos varios      COMFENALCO VALLE EPS
# 761090                    Hogar (ama de casa)               SAVIA SALUD
# 761091  Cesante o sin ocupaci¢n o desempleado  E.P.S.  SANITAS  S.A.-CM
# 761092                    Hogar (ama de casa)           ASMET SALUD ESS
# 761093                    Hogar (ama de casa)                  AIC EPSI
#
#                                                 nom_cbmte
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 761089                             OTRAS FORMAS DE CHOQUE
# 761090  CIERTAS ENFERMEDADES INFECCIOSAS Y PARASITARIA...
# 761091                                CHOQUE HIPOVOLEMICO
# 761092  CIERTAS ENFERMEDADES INFECCIOSAS Y PARASITARIA...
# 761093                             OTRAS FORMAS DE CHOQUE
#
# [761094 rows x 56 columns]

# %% [markdown]
# # 5. Caracterización Epidemiologica
#
# Al inicio de esta seccion se construye df_mag filtrando df_clean por departamento de ocurrencia 47 (Magdalena). Dado que df_clean ya tiene todas las transformaciones y el enriquecimiento por merge aplicados, df_mag hereda esa informacion directamente.
#
# Todas las visualizaciones se guardan en outputs/figures/eda/.
#
# | Sub-sección | Tema | Dataset |
# |---|---|---|
# | 5.1 | Creación de df_mag | df_clean |
# | 5.2 | Cobertura temporal | df_clean |
# | 5.3 | Panorama general nacional | df_clean |
# | 5.4 | Región Caribe | df_clean |
# | 5.5 | Incidencia nacional y Caribe | pendiente DANE |
# | 5.6 | Análisis demográfico | df_mag |
# | 5.7 | Análisis clínico | df_mag |
# | 5.8 | Análisis de mortalidad | df_clean (cod_eve=580) |

# %% [markdown]
# ## 5.1 Creación de df_mag
#
# Se filtra df_clean por cod_dpto_o == 47 para obtener el dataset de trabajo del Magdalena. df_mag hereda todas las transformaciones y el enriquecimiento aplicados en la sección 4.

# %%
df_mag = df_clean[
    df_clean["cod_dpto_o"].astype(str).str.lstrip("0") == "47"
].copy()

BINS_EDAD      = [0, 5, 15, 25, 35, 45, 55, 65, 120]
ETIQUETAS_EDAD = ["0-4", "5-14", "15-24", "25-34", "35-44", "45-54", "55-64", "65+"]
df_mag["grupo_etario"] = pd.cut(
    pd.to_numeric(df_mag["edad_anios"], errors="coerce"),
    bins=BINS_EDAD, labels=ETIQUETAS_EDAD, right=False
)

print(f"df_mag: {len(df_mag):,} registros")
print(f"Municipios: {df_mag['cod_mun_o'].nunique()}")
print(f"Anos: {sorted(df_mag['ano'].dropna().unique().astype(int))}")
# Out:
# df_mag: 13,642 registros
# Municipios: 31
# Anos: [np.int64(2019), np.int64(2020), np.int64(2021), np.int64(2022), np.int64(2023), np.int64(2024)]

# %% [markdown]
# El dataset resultante contiene 13.642 registros. Los 31 municipios distintos incluyen los 30 del departamento más el código 47000 que agrupa registros donde el municipio específico no pudo ser identificado.

# %% [markdown]
# ## 5.2 Cobertura Temporal
#
# Distribucion de casos por año. Permite identificar el rango util de datos y el efecto de eventos externos.

# %%
casos_dengue_anual = (
    df_clean[df_clean["cod_eve"].isin([210, 220])]
    .groupby("ano").size().reset_index(name="casos")
)
muertes_anual = (
    df_clean[df_clean["cod_eve"] == 580]
    .groupby("ano").size().reset_index(name="muertes")
)

data_anual = casos_dengue_anual.merge(muertes_anual, on="ano", how="left")
data_anual["muertes"] = data_anual["muertes"].fillna(0)
anos_orden = sorted(data_anual["ano"].unique().astype(int))
data_anual = data_anual.set_index("ano").loc[anos_orden]
x_pos = range(len(anos_orden))

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

axes[0].bar(x_pos, data_anual["casos"], color=INS_AZUL, edgecolor="white")
axes[0].set_xticks(list(x_pos))
axes[0].set_xticklabels(anos_orden, rotation=30)
axes[0].set_title("Casos de dengue por ano (210+220)")
axes[0].set_ylabel("Casos")

axes[1].bar(x_pos, data_anual["muertes"], color=INS_ROJO, edgecolor="white")
axes[1].set_xticks(list(x_pos))
axes[1].set_xticklabels(anos_orden, rotation=30)
axes[1].set_title("Muertes por dengue por ano (580)")
axes[1].set_ylabel("Muertes")

plt.suptitle("Cobertura temporal del dataset", fontsize=13)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "cobertura_temporal.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# El dataset cubre los seis años completos de 2019 a 2024 sin vacíos temporales. 2024 representa el pico más alto del período con más de 310.000 casos, seguido de 2019 con aproximadamente 125.000. Los años 2020 y 2021 muestran los valores más bajos, patrón coherente con el efecto del COVID-19 sobre la notificación. La mortalidad sigue el mismo patrón con 2024 concentrando la mayoría de las muertes registradas.

# %% [markdown]
# ## 5.3 Panorama General Nacional
#
# Distribución de casos a nivel nacional como contexto para situar al Magdalena dentro del comportamiento del pais.

# %%
df_nacional = df_clean.copy()

# evolución temporal
fig, axes = plt.subplots(2, 2, figsize=(16, 12))
axes = axes.flatten()

df_time = df_nacional.groupby(df_nacional["fec_not"].dt.to_period("M")).size().reset_index(name="casos")
df_time["fec_not"] = df_time["fec_not"].dt.to_timestamp()
axes[0].plot(df_time["fec_not"], df_time["casos"], marker="o", color=INS_AZUL, markersize=3)
axes[0].set_title("Evolución mensual total de casos notificados")
axes[0].set_xlabel("Fecha")
axes[0].set_ylabel("Casos")
axes[0].grid(True, linestyle="--", alpha=0.3)

# evolución por sexo
casos_sexo = (
    df_nacional.groupby([df_nacional["fec_not"].dt.to_period("M"), "sexo"])
    .size().unstack(fill_value=0).reset_index()
)
casos_sexo["fec_not"] = casos_sexo["fec_not"].dt.to_timestamp()
if "m" in casos_sexo.columns:
    axes[1].plot(casos_sexo["fec_not"], casos_sexo["m"], label="Hombres", color=INS_AZUL)
if "f" in casos_sexo.columns:
    axes[1].plot(casos_sexo["fec_not"], casos_sexo["f"], label="Mujeres", color=INS_ROJO)
axes[1].set_title("Evolución mensual por sexo")
axes[1].legend()
axes[1].grid(True, linestyle="--", alpha=0.3)


# casos por semana y año
casos_semana = df_nacional.groupby(["ano", "semana"]).size().reset_index(name="casos")
sns.scatterplot(data=casos_semana, x="semana", y="casos", hue="ano", ax=axes[2], palette="viridis", s=35)
axes[2].set_title("Casos por semana y año")
axes[2].set_xlabel("Semana epidemiológica")
axes[2].set_xlim(1, 53)
axes[2].legend(title="Año", fontsize=8)

axes[3].set_visible(False)

fig.suptitle("Panorama Nacional - Dengue Colombia (evolución temporal)", fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "panorama_nacional_temporal.png", dpi=150, bbox_inches="tight")
plt.show()


# top 10 departamentos
fig2, axes2 = plt.subplots(1, 2, figsize=(16, 6))

top10_dep = (
    df_nacional.groupby(["cod_dpto_o", "nom_dpto_o"]).size().reset_index(name="casos")
    .sort_values("casos", ascending=False).head(10).sort_values("casos")
)
top10_dep["nom_dpto_o"] = top10_dep["nom_dpto_o"].fillna(top10_dep["cod_dpto_o"].astype(str))
colores_top10 = [INS_ROJO if v == 47 else INS_AZUL for v in top10_dep["cod_dpto_o"]]
axes2[1].barh(top10_dep["nom_dpto_o"], top10_dep["casos"], color=colores_top10)
axes2[1].set_title("Top 10 departamentos con más casos")
axes2[1].set_xlabel("Casos")
axes2[1].grid(axis="x", linestyle="--", alpha=0.3)

# mapa coroplético
try:
    casos_dep_geo = df_nacional.groupby("cod_dpto_o").size().reset_index(name="num_casos")
    casos_dep_geo["cod_dpto_o"] = casos_dep_geo["cod_dpto_o"].astype(str).str.zfill(2)
    gdf = gpd.read_file("../data/raw/Colombia.geojson")
    gdf["DPTO"] = gdf["DPTO"].astype(str).str.zfill(2)
    gdf_merged = gdf.merge(casos_dep_geo, left_on="DPTO", right_on="cod_dpto_o", how="left")
    gdf_merged.plot(column="num_casos", ax=axes2[0], legend=True, cmap="Reds",
                    edgecolor="black", linewidth=0.5, missing_kwds={"color": "lightgrey"})
    axes2[0].set_title("Distribución geográfica nacional")
    axes2[0].axis("off")
except Exception as e:
    axes2[0].text(0.5, 0.5, f"GeoJSON no disponible:\n{e}",
                  ha="center", va="center", transform=axes2[0].transAxes, fontsize=9)
    axes2[0].axis("off")

fig2.suptitle("Panorama Nacional - Distribución geográfica", fontsize=15, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "panorama_nacional_geografico.png", dpi=150, bbox_inches="tight")
plt.show()

# mapa de calor mes × año
fig3, ax3 = plt.subplots(figsize=(13, 5))
pivot_tiempo = (
    df_nacional.groupby([df_nacional["fec_not"].dt.year, df_nacional["fec_not"].dt.month])
    .size().unstack(fill_value=0)
)
pivot_tiempo.index.name = "Año"
pivot_tiempo.columns.name = "Mes"
sns.heatmap(pivot_tiempo, cmap="YlOrRd", ax=ax3, cbar_kws={"label": "Casos"},
            linewidths=0.3, linecolor="white")
ax3.set_title("Mapa de calor de casos por mes y año - Nacional")
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "heatmap_mes_ano.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# La evolución temporal confirma que 2024 fue el año de mayor transmisión del período con un pico pronunciado entre abril y julio, seguido de una caída abrupta hacia finales del año. 2019 y 2020 también muestran picos relevantes en el primer semestre, patrón estacional característico del dengue en Colombia asociado a las temporadas de lluvias. Los años 2021 y 2022 representan los valores más bajos del período. La distribución por sexo es prácticamente simétrica en todos los años, sin diferencias marcadas entre hombres y mujeres.
#
# A nivel geográfico, Valle del Cauca concentra la mayor carga de casos del período seguido de Tolima, Santander y Meta. El Magdalena no aparece entre los diez departamentos con mayor carga absoluta, lo que es coherente con su tamaño poblacional relativo. El mapa de calor por mes confirma que el pico de 2024 se concentró entre abril y julio, mientras que los demás años muestran intensidades mucho menores y distribuidas de forma más uniforme a lo largo del año.

# %% [markdown]
# ## 5.4 Región Caribe
#
# Comparación entre los departamentos de la region Caribe. Permite identificar si el Magdalena sigue el patron regional o presenta comportamiento diferencial.

# %%
CODIGOS_CARIBE = {"8", "13", "20", "23", "44", "47", "70", "88"}
cod_dpto_norm = df_clean["cod_dpto_o"].astype(str).str.lstrip("0")

df_caribe = df_clean[cod_dpto_norm.isin(CODIGOS_CARIBE)].copy()
df_mag = df_clean[df_clean["cod_dpto_o"] == 47].copy()

df_caribe["cod_dpto_norm"] = cod_dpto_norm[df_caribe.index]
df_caribe["departamento"] = df_caribe["nom_dpto_o"].fillna(df_caribe["cod_dpto_norm"])
df_caribe["municipio"] = df_caribe["nom_mun_o"].fillna(df_caribe["cod_mun_o"].astype(str))

df_mag["departamento"] = df_mag["nom_dpto_o"].fillna(df_caribe["cod_dpto_norm"])
df_mag["municipio"] = df_mag["nom_mun_o"].fillna(df_caribe["cod_mun_o"].astype(str))

print(f"Registros en Región Caribe: {len(df_caribe):,}")
print(df_caribe["departamento"].value_counts().to_string())

# evolución mensual por departamento
fig, ax = plt.subplots(2,1,figsize=(16, 6))

serie_caribe = (
    df_caribe
    .assign(mes=df_caribe["fec_not"].dt.to_period("M").dt.to_timestamp())
    .groupby(["mes", "departamento"]).size().reset_index(name="casos")
)

serie_magdalena = (
    df_mag
    .assign(mes=df_mag["fec_not"].dt.to_period("M").dt.to_timestamp())
    .groupby(["mes", "departamento"]).size().reset_index(name="casos")
)

sns.lineplot(data=serie_caribe, x="mes", y="casos", hue="departamento",
             ax=ax[0], marker="o", markersize=3)
ax[0].set_title("Evolución mensual de casos - Región Caribe")
ax[0].set_xlabel("Fecha")
ax[0].set_ylabel("Casos")
ax[0].tick_params(axis="x", rotation=45)
ax[0].legend(title="Departamento", bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)
ax[0].grid(True, linestyle="--", alpha=0.3)

sns.lineplot(data=serie_magdalena, x="mes", y="casos",
             ax=ax[1], marker="o", markersize=3, color="#6A0DAD")
ax[1].set_title("Evolución mensual de casos - Departamento del Magdalena")
ax[1].set_xlabel("Fecha")
ax[1].set_ylabel("Casos")
ax[1].tick_params(axis="x", rotation=45)
ax[1].grid(True, linestyle="--", alpha=0.3)

plt.tight_layout()
plt.savefig(DIR_FIGURAS / "caribe_evolucion_mensual.png", dpi=150, bbox_inches="tight")
plt.show()

# total por departamento
fig2, axes2 = plt.subplots(1, 2, figsize=(18, 7))

casos_dep_caribe = (
    df_caribe.groupby("departamento").size().reset_index(name="casos")
    .sort_values("casos", ascending=True)
)
colores_dep = [INS_ROJO if str(d).upper() == "MAGDALENA" else INS_AZUL for d in casos_dep_caribe["departamento"]]
axes2[0].barh(casos_dep_caribe["departamento"], casos_dep_caribe["casos"], color=colores_dep)
axes2[0].set_title("Total de casos por departamento (Magdalena resaltado)")
axes2[0].set_xlabel("Casos")
axes2[0].grid(axis="x", linestyle="--", alpha=0.4)

# top 10 municipios
top_mun_caribe = (
    df_caribe.groupby(["departamento", "municipio"]).size()
    .reset_index(name="casos").sort_values("casos", ascending=False).head(10).sort_values("casos")
)
sns.barplot(data=top_mun_caribe, x="casos", y="municipio",
            hue="departamento", dodge=False, palette="tab10", ax=axes2[1])
axes2[1].set_title("Top 10 municipios con más casos - Región Caribe")
axes2[1].set_xlabel("Casos")
axes2[1].legend(title="Departamento", bbox_to_anchor=(1.02, 1), loc="upper left", fontsize=8)
axes2[1].grid(axis="x", linestyle="--", alpha=0.4)

fig2.suptitle("Región Caribe - Distribución geográfica y municipal", fontsize=14, fontweight="bold", y=1.01)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "caribe_distribucion.png", dpi=150, bbox_inches="tight")
plt.show()

# estacionalidad comparada
dengue_caribe = df_caribe[df_caribe["cod_eve"].isin([210, 220])].copy()
casos_caribe_sem = (
    dengue_caribe.groupby(["departamento", "semana"]).size().reset_index(name="casos")
)

fig4, ax4 = plt.subplots(figsize=(14, 6))
for dpto, grupo in casos_caribe_sem.groupby("departamento"):
    es_magdalena = str(dpto).upper() == "MAGDALENA"
    ax4.plot(grupo["semana"], grupo["casos"], label=dpto,
             color=INS_ROJO if es_magdalena else None,
             linewidth=2.5 if es_magdalena else 1.0,
             zorder=5 if es_magdalena else 2)
ax4.set_title("Estacionalidad comparada - Región Caribe (2019–2024 agregado)")
ax4.set_xlabel("Semana epidemiológica")
ax4.set_ylabel("Casos")
ax4.set_xlim(1, 53)
ax4.legend(title="Departamento", fontsize=8, bbox_to_anchor=(1, 1))
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "caribe_estacionalidad.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Registros en Región Caribe: 180,778
# departamento
# Bolívar                                                     45347
# Atlántico                                                   38797
# Córdoba                                                     24879
# Cesar                                                       23260
# Sucre                                                       23110
# Magdalena                                                   13642
# La Guajira                                                  10612
# Archipiélago de San Andrés, Providencia y Santa Catalina     1131

# %% [markdown]
# El Magdalena registró 13.642 casos en el período, ubicándose en el sexto lugar de los ocho departamentos de la Región Caribe, por encima de La Guajira y el Archipiélago. Santa Marta es el único municipio del departamento que aparece en el top 10 regional con aproximadamente 4.000 casos acumulados, lo que indica una concentración importante de la carga departamental en la capital.
#
# En términos de estacionalidad, Magdalena muestra una curva relativamente estable a lo largo del año sin un pico pronunciado como el que presentan Atlántico y Bolívar en el segundo semestre. Este comportamiento diferencial sugiere una transmisión más sostenida y menos estacional en el departamento.

# %% [markdown]
# ## 5.5 Incidencia Nacional y Caribe
#
# La tasa de incidencia de dengue se calcula como el número de casos confirmados
# por cada 100.000 habitantes en riesgo. El denominador corresponde a la población
# en riesgo estimada a partir de las proyecciones DANE (Censo 2018), aplicando la
# metodología del Lineamiento MSPS/INS 2022 según los criterios de la Tabla 5
# (ver Limitación 1). El análisis se presenta a nivel departamental,
# distrital y regional para el periodo 2019-2024.

# %%
# carga y transformaciones base
dane = pd.read_excel(
    DIR_LOOKUP / "PPED-AreaMun-2018-2042_VP.xlsx",
    sheet_name="PobMunicipalxÁrea",
    dtype=str,
    header=7
)
dane.columns = [str(c).strip().lower() for c in dane.columns]
dane["ano"] = pd.to_numeric(dane["año"], errors="coerce")
dane["dp"] = pd.to_numeric(dane["dp"],   errors="coerce")
dane["mpio"] = pd.to_numeric(dane["mpio"], errors="coerce") 
dane["area_geo"] = dane["área geográfica"].str.strip().str.lower()
dane["poblacion"] = pd.to_numeric(dane["total"], errors="coerce")


dane = dane[dane["ano"].between(2019, 2024)]

# total y rural
dane_total = (
    dane[dane["area_geo"] == "total"]
    [["dp", "mpio", "dpnom", "dpmp", "ano", "poblacion"]]
    .rename(columns={"poblacion": "poblacion_total"})
)
dane_cabecera = (
    dane[dane["area_geo"] == "cabecera municipal"]
    [["mpio", "ano", "poblacion"]]
    .rename(columns={"poblacion": "poblacion_cabecera"})
)
dane_rural = (
    dane[dane["area_geo"] == "centros poblados y rural disperso"]
    [["mpio", "ano", "poblacion"]]
    .rename(columns={"poblacion": "poblacion_rural"})
)

dane_pob = dane_total.merge(dane_cabecera, on=["mpio", "ano"], how="left")
dane_pob = dane_pob.merge(dane_rural, on=["mpio", "ano"], how="left")

print(dane_pob.head())
# Out:
#     dp    mpio      dpnom        dpmp     ano  poblacion_total  \
# 0  5.0  5001.0  Antioquia    Medellín  2019.0        2455336.0
# 1  5.0  5002.0  Antioquia   Abejorral  2019.0          20612.0
# 2  5.0  5004.0  Antioquia    Abriaquí  2019.0           2745.0
# 3  5.0  5021.0  Antioquia  Alejandría  2019.0           4759.0
# 4  5.0  5030.0  Antioquia       Amagá  2019.0          30729.0
#
#    poblacion_cabecera  poblacion_rural
# 0           2409046.0          46290.0
# 1              7847.0          12765.0
# 2               856.0           1889.0
# 3              2576.0           2183.0
# 4             14542.0          16187.0

# %% [markdown]
# Se cargan los municipios con transmisión activa confirmada (baja a muy alta
# transmisión) según el Lineamiento MSPS/INS 2020-2023, que define los municipios
# endémicos sobre los cuales se calculan los indicadores.

# %%
estrat = pd.read_excel(
    DIR_LOOKUP / "estratificacion_arbovirosis_colombia_2020_2023.xlsx",
    dtype=str,
    usecols=["cod_municipio", "cod_departamento", "nivel_riesgo"]
)
estrat["cod_municipio"] = pd.to_numeric(estrat["cod_municipio"],    errors="coerce")
estrat["cod_departamento"] = pd.to_numeric(estrat["cod_departamento"], errors="coerce")

NIVELES_CON_TRANSMISION = [
    "Baja transmisión", "Mediana transmisión",
    "Alta transmisión", "Muy alta transmisión"
]
muns_en_riesgo = estrat[
    estrat["nivel_riesgo"].isin(NIVELES_CON_TRANSMISION)
]["cod_municipio"].unique()

print(f"Municipios Colombia con transmisión activa: {len(muns_en_riesgo)}")
print(f"Municipios Magdalena con transmisión activa: {estrat[(estrat['cod_departamento']==47) & (estrat['nivel_riesgo'].isin(NIVELES_CON_TRANSMISION))].shape[0]}")
print("\nDistribución Magdalena por nivel:")
print(estrat[estrat["cod_departamento"]==47]["nivel_riesgo"].value_counts().to_string())
estrat
# Out:
# Municipios Colombia con transmisión activa: 837
# Municipios Magdalena con transmisión activa: 30
#
# Distribución Magdalena por nivel:
# nivel_riesgo
# Baja transmisión        17
# Mediana transmisión     11
# Muy alta transmisión     1
# Alta transmisión         1
#       cod_municipio  cod_departamento                nivel_riesgo
# 0              5001                 5        Muy alta transmisión
# 1              5002                 5                  Sin riesgo
# 2              5004                 5  Sin transmisión sin vector
# 3              5021                 5  Sin transmisión sin vector
# 4              5030                 5         Mediana transmisión
# ...             ...               ...                         ...
# 1144          97889                97  Sin transmisión sin vector
# 1145          99001                99         Mediana transmisión
# 1146          99524                99         Mediana transmisión
# 1147          99624                99            Baja transmisión
# 1148          99773                99         Mediana transmisión
#
# [1149 rows x 3 columns]

# %% [markdown]
# se hace el calculo del numerador, se incluyen casos de dengue (210) y dengue grave (220) con tipificación de
# cierre confirmada (tip_cas en 2, 3 y 5), notificados en municipios con
# transmisión activa.

# %%
casos_mun = (
    df_clean[
        df_clean["cod_eve"].isin([210, 220]) &
        df_clean["mun_valido"] &
        df_clean["cod_mun_completo"].isin(muns_en_riesgo) &
        df_clean["tip_cas"].isin([2, 3, 5])
    ]
    .groupby(["cod_mun_completo", "ano"])
    .size()
    .reset_index(name="casos")
)

print(casos_mun.head(10))
print(f"\nShape: {casos_mun.shape}")
# Out:
#    cod_mun_completo   ano  casos
# 0              5001  2019   1234
# 1              5001  2020    627
# 2              5001  2021    240
# 3              5001  2022    227
# 4              5001  2023    448
# 5              5001  2024   4926
# 6              5030  2019     14
# 7              5030  2020     83
# 8              5030  2021      1
# 9              5030  2022      2
#
# Shape: (4375, 3)

# %% [markdown]
# Dado que el dato oficial de presencia vectorial por área geográfica no está
# disponible públicamente, la presencia del vector se infiere a partir de la
# transmisión histórica de casos registrada en el campo area del SIVIGILA, bajo
# el supuesto de que la ocurrencia de transmisión implica necesariamente la
# presencia del vector en esa misma área. A partir de esto se aplican tres
# escenarios para asignar la población en riesgo:
#
# - Transmisión urbana y rural simultánea: población total
# - Transmisión únicamente urbana: población de cabecera municipal
# - Transmisión únicamente rural: población de centros poblados y rural disperso

# %%
area_mun = (
    df_clean[
        df_clean["cod_eve"].isin([210, 220]) &
        df_clean["mun_valido"] &
        df_clean["cod_mun_completo"].isin(muns_en_riesgo) &
        df_clean["tip_cas"].isin([2, 3, 5])
    ]
    .assign(
        es_urbano=lambda d: d["area"] == 1,
        es_rural=lambda d: d["area"].isin([2, 3])
    )
    .groupby(["cod_mun_completo", "cod_dpto_o", "ano"])
    .agg(
        tiene_urbano=("es_urbano", "any"),
        tiene_rural=("es_rural", "any")
    )
    .reset_index()
)

denom_mun = area_mun.merge(
    dane_pob[["mpio", "ano", "poblacion_total", "poblacion_rural", "poblacion_cabecera"]],
    left_on=["cod_mun_completo", "ano"],
    right_on=["mpio", "ano"],
    how="left"
).drop(columns="mpio")

denom_mun["pob_denom"] = denom_mun.apply(
    lambda r: r["poblacion_total"] if (r["tiene_urbano"] and r["tiene_rural"])
    else r["poblacion_cabecera"] if r["tiene_urbano"]
    else r["poblacion_rural"],
    axis=1
)

print(denom_mun.head(10))
print(f"\nNulos en pob_denom: {denom_mun['pob_denom'].isna().sum()}")
denom_mun
# Out:
#    cod_mun_completo  cod_dpto_o   ano  tiene_urbano  tiene_rural  \
# 0              5001           5  2019          True         True
# 1              5001           5  2020          True         True
# 2              5001           5  2021          True         True
# 3              5001           5  2022          True         True
# 4              5001           5  2023          True         True
# 5              5001           5  2024          True         True
# 6              5030           5  2019          True         True
# 7              5030           5  2020          True         True
# 8              5030           5  2021          True        False
# 9              5030           5  2022         False         True
#
#    poblacion_total  poblacion_rural  poblacion_cabecera  pob_denom
# 0        2455336.0          46290.0           2409046.0  2455336.0
# 1        2489955.0          48073.0           2441882.0  2489955.0
# 2        2507620.0          48371.0           2459249.0  2507620.0
# 3        2514709.0          48470.0           2466239.0  2514709.0
# 4        2518480.0          48522.0           2469958.0  2518480.0
# 5        2524747.0          48613.0           2476134.0  2524747.0
# 6          30729.0          16187.0             14542.0    30729.0
# 7          31279.0          16350.0             14929.0    31279.0
# 8          31668.0          16429.0             15239.0    15239.0
# 9          31974.0          16465.0             15509.0    16465.0
#
# Nulos en pob_denom: 0
#       cod_mun_completo  cod_dpto_o   ano  tiene_urbano  tiene_rural  \
# 0                 5001           5  2019          True         True
# 1                 5001           5  2020          True         True
# 2                 5001           5  2021          True         True
# 3                 5001           5  2022          True         True
# 4                 5001           5  2023          True         True
# ...                ...         ...   ...           ...          ...
# 4370             99773          99  2020          True         True
# 4371             99773          99  2021          True         True
# 4372             99773          99  2022          True         True
# 4373             99773          99  2023          True         True
# 4374             99773          99  2024          True         True
#
#       poblacion_total  poblacion_rural  poblacion_cabecera  pob_denom
# 0           2455336.0          46290.0           2409046.0  2455336.0
# 1           2489955.0          48073.0           2441882.0  2489955.0
# 2           2507620.0          48371.0           2459249.0  2507620.0
# 3           2514709.0          48470.0           2466239.0  2514709.0
# 4           2518480.0          48522.0           2469958.0  2518480.0
# ...               ...              ...                 ...        ...
# 4370          83751.0          80465.0              3286.0    83751.0
# 4371          88904.0          85478.0              3426.0    88904.0
# 4372          94013.0          90476.0              3537.0    94013.0
# 4373          99157.0          95520.0              3637.0    99157.0
# 4374         104385.0         100644.0              3741.0   104385.0
#
# [4375 rows x 9 columns]

# %% [markdown]
# se realiza el calculo de la incidencia

# %%
incidencia_mun = casos_mun.merge(
    denom_mun[["cod_dpto_o","cod_mun_completo", "ano", "tiene_urbano" ,"pob_denom", "poblacion_total", "poblacion_rural", "poblacion_cabecera"]],
    on=["cod_mun_completo", "ano"],
    how="left"
)
incidencia_mun["tasa"] = incidencia_mun["casos"] / incidencia_mun["pob_denom"] * 100000

print(incidencia_mun.head(10))
print(f"\nNulos en tasa: {incidencia_mun['tasa'].isna().sum()}")
incidencia_mun
# Out:
#    cod_mun_completo   ano  casos  cod_dpto_o  tiene_urbano  pob_denom  \
# 0              5001  2019   1234           5          True  2455336.0
# 1              5001  2020    627           5          True  2489955.0
# 2              5001  2021    240           5          True  2507620.0
# 3              5001  2022    227           5          True  2514709.0
# 4              5001  2023    448           5          True  2518480.0
# 5              5001  2024   4926           5          True  2524747.0
# 6              5030  2019     14           5          True    30729.0
# 7              5030  2020     83           5          True    31279.0
# 8              5030  2021      1           5          True    15239.0
# 9              5030  2022      2           5         False    16465.0
#
#    poblacion_total  poblacion_rural  poblacion_cabecera        tasa
# 0        2455336.0          46290.0           2409046.0   50.257887
# 1        2489955.0          48073.0           2441882.0   25.181178
# 2        2507620.0          48371.0           2459249.0    9.570828
# 3        2514709.0          48470.0           2466239.0    9.026889
# 4        2518480.0          48522.0           2469958.0   17.788507
# 5        2524747.0          48613.0           2476134.0  195.108658
# 6          30729.0          16187.0             14542.0   45.559569
# 7          31279.0          16350.0             14929.0  265.353752
# 8          31668.0          16429.0             15239.0    6.562110
# 9          31974.0          16465.0             15509.0   12.146978
#
# Nulos en tasa: 0
#       cod_mun_completo   ano  casos  cod_dpto_o  tiene_urbano  pob_denom  \
# 0                 5001  2019   1234           5          True  2455336.0
# 1                 5001  2020    627           5          True  2489955.0
# 2                 5001  2021    240           5          True  2507620.0
# 3                 5001  2022    227           5          True  2514709.0
# 4                 5001  2023    448           5          True  2518480.0
# ...                ...   ...    ...         ...           ...        ...
# 4370             99773  2020     39          99          True    83751.0
# 4371             99773  2021     41          99          True    88904.0
# 4372             99773  2022     27          99          True    94013.0
# 4373             99773  2023    169          99          True    99157.0
# 4374             99773  2024     86          99          True   104385.0
#
#       poblacion_total  poblacion_rural  poblacion_cabecera        tasa
# 0           2455336.0          46290.0           2409046.0   50.257887
# 1           2489955.0          48073.0           2441882.0   25.181178
# 2           2507620.0          48371.0           2459249.0    9.570828
# 3           2514709.0          48470.0           2466239.0    9.026889
# 4           2518480.0          48522.0           2469958.0   17.788507
# ...               ...              ...                 ...         ...
# 4370          83751.0          80465.0              3286.0   46.566608
# 4371          88904.0          85478.0              3426.0   46.117160
# 4372          94013.0          90476.0              3537.0   28.719432
# 4373          99157.0          95520.0              3637.0  170.436782
# 4374         104385.0         100644.0              3741.0   82.387316
#
# [4375 rows x 10 columns]

# %% [markdown]
# Colombia cuenta con 12 distritos especiales que el INS reporta como entidades
# territoriales independientes de su departamento. Se separan del cálculo
# departamental para evitar doble conteo en la agregación.

# %%
codigos_distritales = [
    11001,                # Bogotá
    8001,                 # Barranquilla
    13001, 13433,         # Cartagena, Mompox
    47001,                # Santa Marta
    76001, 76109,         # Cali, Buenaventura
    44001,                # Riohacha
    68081,                # Barrancabermeja
    5001, 5837,           # Medellín, Turbo
    52835,                # Tumaco
]

# Departamentos sin sus distritales
incidencia_dpto_ano = (
    incidencia_mun[~incidencia_mun["cod_mun_completo"].isin(codigos_distritales)]
    .groupby(["cod_dpto_o", "ano"])
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
    .merge(
        dane_pob[["dp", "dpnom"]].drop_duplicates(),
        left_on="cod_dpto_o", right_on="dp", how="left"
    )
    .assign(cod_territorio=lambda d: d["cod_dpto_o"], territorio=lambda d: d["dpnom"])
    [["cod_territorio", "territorio", "ano", "casos", "pob_denom", "tasa"]]
)

# Distritales solos
incidencia_distrital_ano = (
    incidencia_mun[incidencia_mun["cod_mun_completo"].isin(codigos_distritales)]
    .groupby(["cod_mun_completo", "ano"])
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
    .merge(
        dane_pob[["mpio", "dpmp"]].drop_duplicates(),
        left_on="cod_mun_completo", right_on="mpio", how="left"
    )
    .assign(cod_territorio=lambda d: d["cod_mun_completo"], territorio=lambda d: d["dpmp"])
    [["cod_territorio", "territorio", "ano", "casos", "pob_denom", "tasa"]]
)

# Territorio final
incidencia_territorio_ano = (
    pd.concat([incidencia_dpto_ano, incidencia_distrital_ano])
    .sort_values(["territorio", "ano"])
    .reset_index(drop=True)
)

print(incidencia_territorio_ano)
# Out:
#      cod_territorio territorio   ano  casos  pob_denom         tasa
# 0                91   Amazonas  2019   1713    62964.0  2720.602249
# 1                91   Amazonas  2020    202    64238.0   314.455618
# 2                91   Amazonas  2021    310    65411.0   473.926404
# 3                91   Amazonas  2022    467    66418.0   703.122647
# 4                91   Amazonas  2023    998    67404.0  1480.624295
# ..              ...        ...   ...    ...        ...          ...
# 253              99    Vichada  2020     54   118879.0    45.424339
# 254              99    Vichada  2021     52   118332.0    43.944157
# 255              99    Vichada  2022     84   131824.0    63.721325
# 256              99    Vichada  2023    198   137429.0   144.074395
# 257              99    Vichada  2024    443   143117.0   309.536952
#
# [258 rows x 6 columns]

# %%
# Agregaciones
incidencia_nacional = (
    incidencia_mun
    .groupby("ano")
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
)

DPTOS_CARIBE = [8, 13, 20, 23, 44, 47, 70, 88]
TERRITORIOS_CARIBE = DPTOS_CARIBE + [8001, 13001, 44001, 47001]

incidencia_caribe = (
    incidencia_territorio_ano[incidencia_territorio_ano["cod_territorio"].isin(TERRITORIOS_CARIBE)]
    .groupby("ano")
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
)

incidencia_magdalena = (
    incidencia_territorio_ano[incidencia_territorio_ano["cod_territorio"] == 47]
    .groupby("ano")
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
)

incidencia_santa_marta = (
    incidencia_territorio_ano[incidencia_territorio_ano["cod_territorio"] == 47001]
    .groupby("ano")
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
)

incidencia_territorio_promedio = (
    incidencia_territorio_ano
    .groupby(["cod_territorio", "territorio"])
    .agg(casos=("casos", "sum"), pob_denom=("pob_denom", "sum"))
    .assign(tasa=lambda d: d["casos"] / d["pob_denom"] * 100000)
    .reset_index()
    .sort_values("tasa", ascending=True)
)

años = incidencia_nacional["ano"].tolist()

fig = plt.figure(figsize=(12, 28))
gs = fig.add_gridspec(3, 1, hspace=0.4)

# Gráfica 1: Tendencia nacional, Caribe y Magdalena
ax1 = fig.add_subplot(gs[0])
ax1.plot(años, incidencia_nacional["tasa"], marker="o", label="Nacional", color="#185FA5", linewidth=2)
ax1.plot(años, incidencia_caribe["tasa"], marker="o", label="Caribe", color="#1D9E75", linewidth=2, linestyle="--")
ax1.plot(años, incidencia_magdalena["tasa"], marker="o", label="Magdalena", color="#D85A30", linewidth=2, linestyle=":")
ax1.set_title("Tasa de incidencia de dengue por 100.000 habitantes, 2019-2024")
ax1.set_xlabel("Año")
ax1.set_ylabel("Tasa x 100.000 hab.")
ax1.legend()
ax1.grid(axis="y", alpha=0.3)

# Gráfica 2: Tasa promedio por territorio
ax2 = fig.add_subplot(gs[1])
ax2.barh(incidencia_territorio_promedio["territorio"], incidencia_territorio_promedio["tasa"], color="#185FA5")
ax2.set_title("Tasa de incidencia promedio por territorio, 2019-2024")
ax2.set_xlabel("Tasa x 100.000 hab.")
ax2.grid(axis="x", alpha=0.3)

# Gráfica 3: Santa Marta vs Magdalena vs Caribe
ax3 = fig.add_subplot(gs[2])
x = range(len(años))
ax3.plot(x, incidencia_caribe["tasa"], marker="o", label="Caribe", color="#1D9E75", linewidth=2)
ax3.plot(x, incidencia_magdalena["tasa"], marker="o", label="Magdalena", color="#D85A30", linewidth=2, linestyle="--")
ax3.plot(x, incidencia_santa_marta["tasa"], marker="o", label="Santa Marta", color="#185FA5", linewidth=2, linestyle=":")
ax3.set_xticks(x)
ax3.set_xticklabels(años)
ax3.set_title("Santa Marta vs Magdalena vs region Caribe - tasa de incidencia por 100.000 hab.")
ax3.set_xlabel("Año")
ax3.set_ylabel("Tasa x 100.000 hab.")
ax3.legend()
ax3.grid(axis="y", alpha=0.3)

plt.savefig(DIR_FIGURAS / "incidencia_nacional_caribe.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Durante el periodo 2019-2024 se identifican dos ciclos epidémicos a nivel nacional: 2019 y 2024, siendo este último el de mayor intensidad con una tasa que supera los 800 casos por 100.000 habitantes, muy por encima de cualquier año anterior. El año 2020 registró la menor incidencia del periodo, atribuible en parte a la reducción en la capacidad de notificación durante la pandemia de COVID-19. La región Caribe mantuvo tasas superiores al promedio nacional entre 2021 y 2022, invirtiéndose esta relación en 2023 cuando el brote nacional superó la incidencia regional, sugiriendo que ese año el dengue afectó con mayor intensidad a territorios que históricamente no eran los más afectados.

# %% [markdown]
# ## 5.6 Analisis Demografico - Magdalena
#
# Distribucion de casos por sexo, grupo etario, pertenencia etnica, regimen de afiliacion (tip_ss), estrato socioeconomico, area de residencia y EAPB.

# %%
mag = df_clean[
    df_clean["cod_eve"].isin([210, 220]) &
    df_clean["mun_valido"] &
    df_clean["cod_mun_completo"].isin(muns_en_riesgo) &
    df_clean["tip_cas"].isin([2, 3, 5]) &
    (df_clean["cod_dpto_o"] == 47)
].copy()

# Mapeos
MAP_SEXO = {"m": "Masculino", "f": "Femenino"}
MAP_TIPSS = {"s": "Subsidiado", "c": "Contributivo", "n": "No asegurado",
             "p": "Excepción", "i": "Indeterminado", "e": "Especial"}
MAP_EAPETN = {1: "Indígena", 2: "ROM", 3: "Raizal", 4: "Palenquero",
              5: "Afrocolombiano", 6: "Ninguno"}
MAP_AREA = {1: "Cabecera municipal", 2: "Centro poblado", 3: "Rural disperso"}

mag["sexo_nom"] = mag["sexo"].map(MAP_SEXO)
mag["tip_ss_nom"] = mag["tip_ss"].map(MAP_TIPSS)
mag["per_etn_nom"] = mag["per_etn"].map(MAP_EAPETN)
mag["area_nom"] = mag["area"].map(MAP_AREA)

# Grupos etarios
bins = [0, 5, 10, 15, 20, 30, 40, 50, 60, 120]
labels = ["0-4", "5-9", "10-14", "15-19", "20-29", "30-39", "40-49", "50-59", "60+"]
mag["grupo_etario"] = pd.cut(mag["edad_anios"], bins=bins, labels=labels, right=False)

fig, axes = plt.subplots(3, 2, figsize=(14, 16))
fig.suptitle("Distribución de casos de dengue - Magdalena 2019-2024", fontsize=14, y=1.01)

# Sexo
ax = axes[0, 0]
sexo_counts = mag["sexo_nom"].value_counts()
ax.bar(sexo_counts.index, sexo_counts.values, color=["#185FA5", "#D85A30"])
ax.set_title("Distribución por sexo")
ax.set_ylabel("Casos")
ax.grid(axis="y", alpha=0.3)
for i, v in enumerate(sexo_counts.values):
    ax.text(i, v + 30, f"{v:,}", ha="center", fontsize=9)

# Grupo etario
ax = axes[0, 1]
edad_counts = mag["grupo_etario"].value_counts().sort_index()
ax.bar(edad_counts.index.astype(str), edad_counts.values, color="#185FA5")
ax.set_title("Distribución por grupo etario")
ax.set_ylabel("Casos")
ax.grid(axis="y", alpha=0.3)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right")

# Régimen de afiliación
ax = axes[1, 0]
tipss_counts = mag["tip_ss_nom"].value_counts()
ax.barh(tipss_counts.index, tipss_counts.values, color="#185FA5")
ax.set_title("Distribución por régimen de afiliación")
ax.set_xlabel("Casos")
ax.grid(axis="x", alpha=0.3)
for i, v in enumerate(tipss_counts.values):
    ax.text(v + 20, i, f"{v:,}", va="center", fontsize=9)

# Pertenencia étnica
ax = axes[1, 1]
etn_counts = mag["per_etn_nom"].value_counts()
ax.barh(etn_counts.index, etn_counts.values, color="#185FA5")
ax.set_title("Distribución por pertenencia étnica")
ax.set_xlabel("Casos")
ax.grid(axis="x", alpha=0.3)

# Estrato
ax = axes[2, 0]
estrato_counts = mag["estrato"].value_counts().sort_index()
ax.bar(estrato_counts.index.astype(str), estrato_counts.values, color="#185FA5")
ax.set_title("Distribución por estrato socioeconómico")
ax.set_ylabel("Casos")
ax.grid(axis="y", alpha=0.3)

# Área de residencia
ax = axes[2, 1]
area_counts = mag["area_nom"].value_counts()
ax.barh(area_counts.index, area_counts.values, color="#185FA5")
ax.set_title("Distribución por área de residencia")
ax.set_xlabel("Casos")
ax.grid(axis="x", alpha=0.3)

plt.tight_layout()
plt.savefig(DIR_FIGURAS / "distribucion_demografica.png", dpi=150, bbox_inches="tight")
plt.show()

# EAPB top 10
fig, ax = plt.subplots(figsize=(10, 6))
eapb_counts = mag["nom_ase"].value_counts().head(10).sort_values()
ax.barh(eapb_counts.index, eapb_counts.values, color="#185FA5") #type: ignore
ax.set_title("Top 10 EAPB por número de casos — Magdalena 2019-2024")
ax.set_xlabel("Casos")
ax.grid(axis="x", alpha=0.3)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "top10_eapb.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Los casos de dengue en Magdalena durante 2019-2024 afectaron predominantemente
# a población masculina, en edad escolar y adolescente (grupos 5-9 y 10-14
# años), de estrato 1, afiliada al régimen subsidiado y residente
# en cabecera municipal. Este perfil es consistente con el patrón nacional de dengue y refleja
# la concentración de la enfermedad en población urbana de bajos recursos.
#
# Las EAPB con mayor carga de casos son COOSALUD ESS EPS-S, Salud Total SA EPS y
# Mutual Ser ESS, todas del régimen subsidiado, lo que refuerza el perfil
# socioeconómico predominante. La distribución por área de residencia confirma el
# predominio urbano de la transmisión de casos en cabecera municipal,
# coherente con la naturaleza urbana del vector Aedes aegypti.

# %% [markdown]
# ## 5.7 Análisis Clinico - Magdalena
#
# Caracterización clinica de los casos: tipo de clasificacion (tip_cas), hospitalizacion (pac_hos), condición final (con_fin) y distribución por tipo de evento (210 vs 220).

# %%
mag_cli = df_clean[
    df_clean["cod_eve"].isin([210, 220, 580]) &
    df_clean["mun_valido"] &
    df_clean["cod_mun_completo"].isin(muns_en_riesgo) &
    (df_clean["cod_dpto_o"] == 47)
].copy()

MAP_TIPCAS = {1: "Sospechoso", 2: "Probable", 3: "Conf. laboratorio",
              4: "Conf. clínica", 5: "Conf. nexo epi."}
MAP_ESTADO = {1: "Sospechoso", 2: "Probable", 3: "Conf. laboratorio",
              4: "Conf. clínica", 5: "Conf. nexo epi."}
MAP_PACHOS = {1: "Hospitalizado", 2: "No hospitalizado"}
MAP_CONFIN = {1: "Vivo", 2: "Muerto"}
MAP_FUENTE = {1: "Notificación rutinaria", 2: "Búsqueda activa institucional",
              3: "Vigilancia intensificada", 4: "Búsqueda activa comunitaria",
              5: "Investigaciones"}
MAP_EVE    = {210: "Dengue (210)", 220: "Dengue grave (220)", 580: "Mortalidad (580)"}

mag_cli["tip_cas_nom"]    = mag_cli["tip_cas"].map(MAP_TIPCAS)
mag_cli["estado_nom"]     = mag_cli["estado_final_de_caso"].map(MAP_ESTADO)
mag_cli["pac_hos_nom"]    = mag_cli["pac_hos"].map(MAP_PACHOS)
mag_cli["con_fin_nom"]    = mag_cli["con_fin"].map(MAP_CONFIN)
mag_cli["fuente_nom"]     = mag_cli["fuente"].map(MAP_FUENTE)
mag_cli["cod_eve_nom"]    = mag_cli["cod_eve"].map(MAP_EVE)
mag_cli["hospitalizado"]  = mag_cli["pac_hos"] == 1

fig, axes = plt.subplots(2, 2, figsize=(14, 12))
fig.suptitle("Análisis clínico — Magdalena 2019-2024", fontsize=14, y=1.01)
axes = axes.flatten()

# Clasificación inicial vs final
tip_ini = mag_cli["tip_cas_nom"].value_counts().sort_values()
axes[0].barh(tip_ini.index, tip_ini.values, color="#185FA5")
axes[0].set_title("Clasificación inicial (tip_cas)")
axes[0].set_xlabel("Registros")
axes[0].grid(axis="x", alpha=0.3)

tip_fin = mag_cli["estado_nom"].value_counts().sort_values()
axes[1].barh(tip_fin.index, tip_fin.values, color="#D85A30")
axes[1].set_title("Clasificación final (estado_final_de_caso)")
axes[1].set_xlabel("Registros")
axes[1].grid(axis="x", alpha=0.3)

cambios = (mag_cli["tip_cas"] != mag_cli["estado_final_de_caso"]).sum()
pct_cambios = cambios / len(mag_cli) * 100
print(f"Registros que cambian de clasificación: {cambios:,} ({pct_cambios:.1f}%)")

# Hospitalización por año y tipo de caso
hosp_pct = (
    mag_cli[mag_cli["cod_eve"].isin([210, 220])]
    .groupby(["ano", "cod_eve_nom"])["hospitalizado"]
    .mean().mul(100).reset_index()
    .pivot(index="ano", columns="cod_eve_nom", values="hospitalizado")
    .fillna(0)
)
hosp_pct.plot(kind="bar", ax=axes[2], color=["#185FA5", "#D85A30"], edgecolor="white")
axes[2].set_title("Porcentaje de hospitalizados por año y tipo de caso")
axes[2].set_xlabel("Año")
axes[2].yaxis.set_major_formatter(mticker.PercentFormatter())
axes[2].legend(fontsize=9)
axes[2].tick_params(axis="x", rotation=45)
axes[2].grid(axis="y", alpha=0.3)

# Condición final por tipo de caso
pivot_cf = (
    mag_cli.groupby(["cod_eve_nom", "con_fin_nom"])
    .size().unstack(fill_value=0)
)
pivot_cf.plot(kind="bar", ax=axes[3], color=["#D85A30", "#185FA5"], edgecolor="white")
axes[3].set_title("Condición final por tipo de caso")
axes[3].set_xlabel("")
axes[3].legend(fontsize=9)
axes[3].tick_params(axis="x", rotation=15)
axes[3].grid(axis="y", alpha=0.3)

plt.tight_layout()
plt.savefig(DIR_FIGURAS / "analisis_clinico.png", dpi=150, bbox_inches="tight")
plt.show()

# Fuente de notificación
fig, axes = plt.subplots(1, 2, figsize=(16, 6))
fig.suptitle("Fuente de notificación - Magdalena 2019-2024", fontsize=13)

# Pie con todas
fuente_counts = mag_cli["fuente_nom"].value_counts()
wedges, texts, autotexts = axes[0].pie(
    fuente_counts.values,
    labels=None,
    autopct="%1.1f%%",
    colors=["#185FA5", "#D85A30", "#1D9E75", "#F5A623", "#9B59B6"],
    pctdistance=0.75,
    startangle=90
)
axes[0].legend(
    wedges, fuente_counts.index,
    loc="lower center",
    bbox_to_anchor=(0.5, -0.15),
    fontsize=9,
    ncol=1
)
axes[0].set_title("Distribución total")

# Barras sin notificación rutinaria
fuente_sin_rutinaria = fuente_counts[fuente_counts.index != "Notificación rutinaria"].sort_values()
total = fuente_counts.sum()

axes[1].barh(fuente_sin_rutinaria.index, fuente_sin_rutinaria.values, color="#185FA5")
axes[1].set_title("Fuentes alternativas (excluye notificación rutinaria)")
axes[1].set_xlabel("Casos")
axes[1].grid(axis="x", alpha=0.3)
for i, v in enumerate(fuente_sin_rutinaria.values):
    pct = v / total * 100
    axes[1].text(v + 2, i, f"{v:,} ({pct:.1f}%)", va="center", fontsize=9)

plt.tight_layout()
plt.savefig(DIR_FIGURAS / "fuente_notificacion.png", dpi=150, bbox_inches="tight")
plt.show()
# Out:
# Registros que cambian de clasificación: 2,131 (15.6%)

# %% [markdown]
# El análisis clínico muestra que la clasificacion predominante es confirmado por laboratorio, lo cual es coherente según lo indica el protocolo del INS. La hospitalización afecta consistentemente a más del 85% de los casos de dengue grave (220) en todos los años, mientras que para dengue no grave (210) oscila entre el 50% y el 70%, con una tendencia descendente desde 2021 que podría reflejar cambios en los criterios de manejo ambulatorio. La condición final confirma que la gran mayoría de los casos de dengue no grave sobreviven, mientras que la mortalidad, aunque visualmente marginal en escala absoluta, se concentra en los registros de código 580.
#
# La fuente de notificación fue predominantemente rutinaria (96,1%), la búsqueda activa institucional representó el
# 3,5% restante de relevancia, mientras que la búsqueda activa comunitaria, la
# vigilancia intensificada y las investigaciones aportaron menos del 0,5% en conjunto.

# %% [markdown]
# ## 5.8 Análisis de Mortalidad - Magdalena
#
# Análisis de los casos con cod_eve = 580: distribucion temporal, grupo etario, causa basica de muerte (cbmte/CIE-10), EAPB y UPGD notificadora.

# %%
mag_580 = df_clean[
    (df_clean["cod_eve"] == 580) &
    (df_clean["cod_dpto_o"] == 47)
].copy()

bins = [0, 5, 10, 15, 20, 30, 40, 50, 60, 120]
labels = ["0-4", "5-9", "10-14", "15-19", "20-29", "30-39", "40-49", "50-59", "60+"]
mag_580["grupo_etario"] = pd.cut(mag_580["edad_anios"], bins=bins, labels=labels, right=False)

fig, axes = plt.subplots(2, 2, figsize=(18, 14))
fig.suptitle("Análisis de mortalidad por dengue - Magdalena 2019-2024", fontsize=14, y=1.01)
axes = axes.flatten()

# Muertes por año
muertes_ano = mag_580.groupby("ano").size().reset_index(name="muertes")
axes[0].bar(muertes_ano["ano"], muertes_ano["muertes"], color="#D85A30")
axes[0].set_title("Muertes por año")
axes[0].set_ylabel("Muertes")
axes[0].grid(axis="y", alpha=0.3)
for i, row in muertes_ano.iterrows():
    axes[0].text(row["ano"], row["muertes"] + 0.1, str(row["muertes"]), ha="center", fontsize=9)

# Grupo etario
grupo_580 = mag_580["grupo_etario"].value_counts().sort_index()
axes[1].bar(grupo_580.index.astype(str), grupo_580.values, color="#D85A30")
axes[1].set_title("Fallecidos por grupo etario")
axes[1].set_xlabel("Grupo etario")
axes[1].set_ylabel("Muertes")
axes[1].grid(axis="y", alpha=0.3)

# Causa básica de muerte
cbmte_counts = mag_580["nom_cbmte"].value_counts().sort_values()
etiquetas = [t[:40] + "..." if len(t) > 40 else t for t in cbmte_counts.index]
axes[2].barh(etiquetas, cbmte_counts.values, color="#D85A30")
axes[2].set_title("Causa básica de muerte (CIE-10)")
axes[2].set_xlabel("Muertes")
axes[2].grid(axis="x", alpha=0.3)
axes[2].tick_params(axis="y", labelsize=9)
for i, v in enumerate(cbmte_counts.values):
    axes[2].text(v + 0.1, i, str(v), va="center", fontsize=9)

# EAPB
ase_counts = mag_580["nom_ase"].value_counts().sort_values()
axes[3].barh(ase_counts.index, ase_counts.values, color="#D85A30")
axes[3].set_title("EAPB con mayor número de muertes")
axes[3].set_xlabel("Muertes")
axes[3].grid(axis="x", alpha=0.3)
axes[3].tick_params(axis="y", labelsize=9)
for i, v in enumerate(ase_counts.values):
    axes[3].text(v + 0.1, i, str(v), va="center", fontsize=9)

plt.tight_layout(pad=3.0)
plt.savefig(DIR_FIGURAS / "mortalidad.png", dpi=150, bbox_inches="tight")
plt.show()

# UPGD
fig, ax = plt.subplots(figsize=(10, 6))
upgd_counts = mag_580["nom_upgd"].value_counts().sort_values()
ax.barh(upgd_counts.index, upgd_counts.values, color="#D85A30") #type: ignore
ax.set_title("UPGD con mayor número de muertes notificadas - Magdalena 2019-2024")
ax.set_xlabel("Muertes")
ax.grid(axis="x", alpha=0.3)
for i, v in enumerate(upgd_counts.values):
    ax.text(v + 0.1, i, str(v), va="center", fontsize=9)
plt.tight_layout()
plt.savefig(DIR_FIGURAS / "mortalidad_upgd.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# Durante el periodo 2019-2024 se registraron 28 muertes por dengue en Magdalena,
# con 2023 como el año más crítico concentrando 9 fallecimientos (32,1% del total),
# seguido de 2020 con 6 muertes. El perfil etario de los fallecidos muestra una
# distribución bimodal con mayor concentración en los grupos de 0-4 y 5-9 años,
# evidenciando la alta vulnerabilidad de la población pediátrica, y un segundo pico
# en el grupo de 15-19 años y adultos mayores de 60 años.
#
# La causa básica de muerte predominante fue clasificada bajo el capítulo de ciertas
# enfermedades infecciosas y parasitarias con 20 casos, seguida de choque
# hipovolémico con 5 casos, consistente con la fisiopatología del dengue grave.
# Mutual Ser ESS concentró el mayor número de fallecidos con 9 casos, mientras que
# los Centros Hospitalarios del Caribe SAS y el Hospital Universitario Fernando
# Troconis fueron las UPGD con mayor número de muertes notificadas, sugiriendo que
# los casos más graves son referidos a instituciones de mayor complejidad ubicadas
# fuera del departamento.

# %% [markdown]
# # 6. Conclusiones y Decisiones
#
# ## 6.1 Principales Hallazgos
#
# El dataset cubre 2019-2024 sin vacíos y conserva integridad para canal endémico
# (mínimo cinco años). Magdalena registró 13.642 casos confirmados de dengue
# (210+220), sexto entre los ocho departamentos del Caribe, con Santa Marta
# concentrando la mayor carga departamental y siendo el único
# municipio del top 10 regional.
#
# La calidad general es alta: las variables núcleo superan 97% de completitud,
# los nulos estructurales (FEC_HOS, sem_ges, FEC_DEF, CBMTE) son esperados, y
# el 99,71% de los registros tiene municipio válido contra DIVIPOLA.
#
# ## 6.2 Limpieza para el pipeline en clean.py
#
# El módulo implementa un Pipeline de scikit-learn con ColumnTransformer
# que reproduce, en este orden, las transformaciones validadas en la sección 4:
#
# 1. Descarte de 26 columnas: variables sin valor analítico (CONSECUTIVE,
#    consecutive_origen, consecutive_12, Particion, COD_SUB, COD_PRE, GRU_POB,
#    FEC_ARC_XL, FEC_AJU, FM_*, va_sispro, CER_DEF) y variables que violan no
#    transitividad (nombres redundantes con códigos, FECHA_NTO).
# 2. Estandarización a minúsculas de nombres de columna y de contenido de
#    variables de texto.
# 3. Conversión de tipos: fechas a datetime, ocupacion a Float64, resto a Int64.
# 4. Construcción de edad_anios con divisores {1, 12, 365, 8760, 525600}
#    según uni_med, imputación a nulo de valores > 120 o negativos, y descarte
#    de edad y uni_med.
# 5. Validación geográfica: construcción de cod_mun_completo y marcado de
#    mun_valido contra DIVIPOLA. Los inválidos se conservan con el flag, no
#    se eliminan.
# 6. Enriquecimiento por left joins con DIVIPOLA, paises, ocupaciones (con
#    cod_antiguo como clave secundaria), aseguradoras y CIE-10 previa
#    corrección de códigos (j15x->j159, i49x->i499, d65->d65x; placeholders a nulo).
#
# Salida: data/processed/dengue_clean.parquet con 56 columnas.
#
# ## 6.3 Limitaciones
#
# Limitación 1 - Denominador (población en riesgo): <br>
# El lineamiento metodológico del MSPS/INS estima la población en riesgo cruzando la presencia del vector por área geográfica con la transmisión de casos por área geográfica según la Tabla 5. Dado que el dato oficial de presencia vectorial desagregado por área no está disponible públicamente, este estudio infiere la presencia del vector por área geográfica directamente a partir de la transmisión histórica de casos registrada en el campo area del SIVIGILA, bajo el supuesto epidemiológicamente válido de que la ocurrencia de transmisión implica necesariamente la presencia del vector en esa misma área. Este supuesto está respaldado por los registros SIVIGILA que muestran que el 82,6% de los casos de dengue en Colombia se presentaron en cabeceras municipales y el 17,4% en centros poblados y rural disperso, patrón consistente con estudios entomológicos que confirman que la mayor probabilidad de presencia del vector se concentra en áreas cercanas a los centros urbanos (Conde et al., Biomédica, 2017), mientras que la presencia en áreas rurales ha sido documentada exclusivamente en municipios con transmisión rural activa (Ruiz-López et al., Biomédica, 2016). Bajo esta lógica, se asume presencia vectorial en cabecera municipal para los municipios con transmisión urbana confirmada, y presencia en centros poblados y rural disperso para los municipios con transmisión rural confirmada, aplicando tres escenarios: transmisión urbana y rural simultánea = población total; transmisión únicamente urbana = población de cabecera municipal; transmisión únicamente rural = población de centros poblados y rural disperso. Esta aproximación fue validada contra los datos de población en riesgo publicados oficialmente por el MSPS para el periodo 2020-2022, único periodo con información pública disponible, obteniéndose valores consistentes. Para 2023 y 2024 no existe archivo oficial publicado, por lo que se aplica la misma metodología.
#
# Limitación 2 - Vigencia de la estratificación: <br>
# La clasificación de riesgo del lineamiento MSPS/INS aplica para el periodo 2020-2023 y fue construida con datos epidemiológicos 2014-2019. Este estudio asume su validez para todo el periodo 2019-2024. La comparación con el Informe de Evento Dengue 2024 del INS evidencia cambios en la clasificación de al menos 5 municipios, entre ellos Armenia, Girardot y Cartago, que ascendieron a muy alta transmisión, confirmando que la dinámica de transmisión ha cambiado y que la estratificación puede subestimar el riesgo real en años recientes.
#
# Limitación 3 - Clasificación clínica del dengue: <br>
# SIVIGILA registra dengue sin signos de alarma, dengue con signos de alarma y dengue grave como categorías clínicas diferenciadas, así como los grupos de síntomas asociados. Sin embargo, el portal público de microdatos del SIVIGILA no expone estas variables de clasificación clínica ni el detalle sintomático en las bases de datos descargables, limitando el análisis a la ocurrencia de casos confirmados. Por tanto, este estudio no desagrega por severidad clínica ni por perfil sintomático, lo que restringe el análisis de la carga de enfermedad grave y la caracterización clínica de los casos. Para acceder a esta información se requeriría una solicitud formal de datos al INS, lo cual está fuera del alcance de este estudio.
#
# Limitación 4 - Acceso y actualización de los datos: <br>
# Los microdatos del SIVIGILA están disponibles únicamente a través de descarga manual de archivos Excel en el portal público del INS, sin acceso mediante API ni mecanismos de consulta automatizada. Esto implica que el periodo de análisis está limitado a los datos disponibles al momento de la descarga, siendo 2024 el último año con información consolidada accesible. No es posible incorporar datos más recientes ni mantener el sistema actualizado de forma automática sin una nueva descarga manual, lo que limita la capacidad del dashboard para reflejar la situación epidemiológica en tiempo real.
# Para abordar esta limitación, el sistema contempla un mecanismo de actualización de datos que permite incorporar nuevos periodos sin modificar el código. Esto es viable porque los microdatos del SIVIGILA mantienen una estructura de columnas consistente entre años, lo que permite que el pipeline de procesamiento opere de forma estandarizada independientemente del año incorporado. De esta manera, aunque la actualización no es automática, el sistema puede extenderse a nuevos periodos con una intervención mínima, preservando la reproducibilidad y trazabilidad del proceso.
